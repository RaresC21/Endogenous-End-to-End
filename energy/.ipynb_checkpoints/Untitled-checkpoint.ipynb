# %%
import pandas as pd
import numpy as np

from datetime import datetime as dt
import pytz
from pandas.tseries.holiday import USFederalHolidayCalendar

try: import setGPU
except ImportError: pass
import warnings
import torch

import model_classes, nets
from constants import *

from model_classes import SolvePointQP

from data import get_data, get_decision_mask, get_decision_mask_

# %load_ext autoreload
# %autoreload 2

warnings.simplefilter("ignore")

DEVICE = "cpu"
if torch.cuda.is_available(): 
    DEVICE = "cuda"
print("DEVICE", DEVICE, "hi")

X_train, Y_train, X_test, Y_test, X_train_pt, Y_train_pt, X_test_pt, Y_test_pt = get_data(DEVICE) 
variables = {'X_train_': X_train_pt, 'Y_train_': Y_train_pt, 
        'X_test_': X_test_pt, 'Y_test_': Y_test_pt}

params = {"n": 24, "c_ramp": 0.4, "gamma_under": 50, "gamma_over": 0.5}

mask = get_decision_mask(Y_train_pt, DEVICE)

EPOCHS_rmse = 200

print("TRAINING 2-STAGE")
model_rmse = model_classes.Net(X_train[:,:-1], Y_train, [200, 200]).to(DEVICE)
model_rmse = nets.run_rmse_net(model_rmse, variables, X_train, Y_train, EPOCHS_rmse)
model_rmse.eval()

EPOCHS_e2e = 200
# Out:
# DEVICE cuda hi
# TRAINING 2-STAGE

# %%
print("TRAINING END-to-END")
end_to_end_net = nets.train_end_to_end(X_train[:,:-1], Y_train, variables, params, 400, DEVICE)
end_to_end_net.eval()
# Out:
# TRAINING END-to-END
# epoch: 0   7.076281595230102
# epoch: 40   0.5060939967632294
# epoch: 80   0.5236818462610244
# epoch: 120   0.4743406862020493
# epoch: 160   0.4059876769781113
# epoch: 200   0.454367795586586
# epoch: 240   0.4150490939617157
# epoch: 280   0.43022537529468535
# epoch: 320   0.39918155074119566
# epoch: 360   0.36887070834636687
# Net(
#   (lin): Linear(in_features=149, out_features=24, bias=True)
#   (net): Sequential(
#     (0): Linear(in_features=149, out_features=200, bias=True)
#     (1): BatchNorm1d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Linear(in_features=200, out_features=200, bias=True)
#     (5): BatchNorm1d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.2, inplace=False)
#     (8): Linear(in_features=200, out_features=24, bias=True)
#   )
# )

# %%
print("TRAIN P-MODEL")
p_net = nets.train_pnet(end_to_end_net, X_train_pt, Y_train_pt, params, 4000, DEVICE)
p_net.eval();
# Out:
# TRAIN P-MODEL
# epoch: 0   0.6573361301651368
# epoch: 400   0.3190522448718548
# epoch: 800   0.2999183376133442
# epoch: 1200   0.27544659331440924
# epoch: 1600   0.2560316100716591
# epoch: 2000   0.21483309477567672
# epoch: 2400   0.20836980134248734
# epoch: 2800   0.162343715056777
# epoch: 3200   0.16640380404889585
# epoch: 3600   0.1537547094374895

# %%
print("TRAIN F-MODEL")
# f_net = model_classes.FNet(X_train[:,:-1], Y_train, [200, 200]).to(DEVICE)
f_net = nets.train_fnet(f_net, p_net, X_train[:,:-1], Y_train, variables, params, 2000, DEVICE)
f_net = nets.train_fnet(f_net, p_net, X_train[:,:-1], Y_train, variables, params, 1000, DEVICE)

end_to_end_net.eval()
f_net.eval()
# Out:
# TRAIN F-MODEL
# epoch: 0   6.316125539668764
# epoch: 20   2.021723942467943
# epoch: 40   1.3697894487716258
# epoch: 60   0.7491422634012997
# epoch: 80   0.5837190938461572
# epoch: 100   0.4810561820864677
# epoch: 120   0.3526567765045911
# epoch: 140   0.3228773647360504
# epoch: 160   0.25604692070744933
# epoch: 180   0.2006636093277484
# epoch: 200   0.20967606752645224
# epoch: 220   0.1639321044832468
# epoch: 240   0.13132232539821417
# epoch: 260   0.11149565057829022
# epoch: 280   0.08247498942539096
# epoch: 300   0.07197086235508322
# epoch: 320   0.06981588509865105
# epoch: 340   0.05129634535871446
# epoch: 360   0.044604587403591724
# epoch: 380   0.040130992438644174
# epoch: 400   0.03476650718133897
# epoch: 420   0.032404085197485985
# epoch: 440   0.025339666465297343
# epoch: 460   0.021650879108347
# epoch: 480   0.02496978293871507
# epoch: 500   0.023879343215376138
# epoch: 520   0.021281579758506267
# epoch: 540   0.01699419452343136
# epoch: 560   0.01923705095425248
# epoch: 580   0.017375068094115705
# epoch: 600   0.017247190531343222
# epoch: 620   0.01655743149924092
# epoch: 640   0.01722524838056415
# epoch: 660   0.016133708009729162
# epoch: 680   0.01492860117694363
# epoch: 700   0.012442258636001497
# epoch: 720   0.012155108947772532
# epoch: 740   0.01206124788732268
# epoch: 760   0.01284886668145191
# epoch: 780   0.01569123281049542
# epoch: 800   0.010772400350542739
# epoch: 820   0.010363250763621181
# epoch: 840   0.009242227340582759
# epoch: 860   0.009852376625640319
# epoch: 880   0.013691356257768348
# epoch: 900   0.009680341450148263
# epoch: 920   0.008882022285833955
# epoch: 940   0.009683237142162397
# epoch: 960   0.009803060775157064
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 3
#       1 print("TRAIN F-MODEL")
#       2 # f_net = model_classes.FNet(X_train[:,:-1], Y_train, [200, 200]).to(DEVICE)
# ----> 3 f_net = nets.train_fnet(f_net, p_net, X_train[:,:-1], Y_train, variables, params, 2000, DEVICE)
#       5 end_to_end_net.eval()
#       6 f_net.eval()
#
# File ~/Rares/Endogenous/energy/nets.py:187, in train_fnet(model, p_net, xx, yy, variables, params, EPOCHS, DEVICE)
#     184 loss_true = task_loss(v_true, y, params)
#     185 loss = torch.mean(((loss_mine - loss_true) ** 2))
# --> 187 loss.backward()
#     188 optimizer.step()
#     190 losses.append(loss.cpu().item())
#
# File ~/my-conda-envs/rares_env/lib/python3.12/site-packages/torch/_tensor.py:525, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     515 if has_torch_function_unary(self):
#     516     return handle_torch_function(
#     517         Tensor.backward,
#     518         (self,),
#    (...)
#     523         inputs=inputs,
#     524     )
# --> 525 torch.autograd.backward(
#     526     self, gradient, retain_graph, create_graph, inputs=inputs
#     527 )
#
# File ~/my-conda-envs/rares_env/lib/python3.12/site-packages/torch/autograd/__init__.py:267, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     262     retain_graph = create_graph
#     264 # The reason we repeat the same comment below is that
#     265 # some Python versions print out the first line of a multi-line function
#     266 # calls in the traceback and some print out the last line
# --> 267 _engine_run_backward(
#     268     tensors,
#     269     grad_tensors_,
#     270     retain_graph,
#     271     create_graph,
#     272     inputs,
#     273     allow_unreachable=True,
#     274     accumulate_grad=True,
#     275 )
#
# File ~/my-conda-envs/rares_env/lib/python3.12/site-packages/torch/autograd/graph.py:744, in _engine_run_backward(t_outputs, *args, **kwargs)
#     742     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     743 try:
# --> 744     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     745         t_outputs, *args, **kwargs
#     746     )  # Calls into the C++ engine to run the backward pass
#     747 finally:
#     748     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
reward_learner = nets.train_reward_learner(p_net, X_train[:,:-1], Y_train, variables, params, 300, DEVICE)
# Out:
# 0 0.9579654678415793
# 20 0.11083442818373442
# 40 0.0791346319951117
# 60 0.06070086646825075
# 80 0.053131419774144886
# 100 0.043915288140997294
# 120 0.03196462943218648
# 140 0.026659036814235152
# 160 0.021565336496569217
# 180 0.02075129225384444
# 200 0.018217365210875868
# 220 0.016212412170134485
# 240 0.019526479167398067
# 260 0.014879128369502724
# 280 0.014612635248340666

# %%
all_rewards = []
for w in range(24):
    r = reward_learner(X_test_pt, w).cpu().detach()
    all_rewards.append(list(r))
reward_losses = []
# print(reward_actions.shape)
all_rewards = np.array(all_rewards)
reward_actions = np.argmin(all_rewards, axis=0)
print(all_rewards.shape)
print(reward_actions.shape)
# Out:
# (24, 639)
# (639,)

# %%
def task_loss_no_mean(Y_sched, Y_actual, params):
    return (params["gamma_under"] * torch.clamp(Y_actual - Y_sched, min=0) + 
        params["gamma_over"] * torch.clamp(Y_sched - Y_actual, min=0))

def pred_obj(x, w): 
    f_pred = f_net(x, w)
    m = get_decision_mask_(f_pred, DEVICE, w)

    p_pred = p_net(x, f_pred, m)

    v2 = p_pred[:,w:]
    v1 = p_net(x, torch.zeros_like(f_pred), torch.zeros_like(f_pred))[:,:w]
    # v1 = f_pred[:,:w]
    
    # print(e_pred)
    v = torch.cat((v1, v2), 1)

    loss = nets.task_loss(v, f_pred, params).mean()
    return loss.item()


def eval_decision(x, y, w):
    f_pred = f_net(x, w)
    m = get_decision_mask_(y, DEVICE, w)

    p_pred = p_net(x, y, m)
    
    v1 = p_net(x, y, torch.zeros_like(y))[:,:w]
    # v1 = f_pred[:,:w]
    v2 = p_pred[:,w:]
            
    v = torch.cat((v1, v2), 1)

    loss = nets.task_loss(v, y, params).mean()
    return loss.item()

# %%
vanilla = [] 
ours = [] 
random = []
optimal = []
two_stage = []
all_costs = []
end_to_end_net.eval()
f_net.eval()
p_net.eval()
reward_losses = []


for indx in range(len(X_test_pt)):
# for indx in [2]:
    X_t = X_test_pt[indx:indx+1,:]
    Y_t = Y_test_pt[indx:indx+1,:]
    # X_t = X_train_pt[indx:indx+1,:]
    # Y_t = Y_train_pt[indx:indx+1,:]

    # e2e = nets.task_loss(end_to_end_net.predict(X_t), Y_t, params).mean().item()
    e2e_pred = p_net(X_t, torch.zeros_like(Y_t), torch.zeros_like(Y_t))
    e2e = nets.task_loss(e2e_pred, Y_t, params).mean().item() 

    ts = nets.task_loss(model_rmse(X_t), Y_t, params).mean().item()
    
    print("end-to-end cost:", e2e)
    print("2-stage    cost:", ts)

    a = 0.0
    best_cost = 1e5 
    best_w = -1
    cur_costs = [] 
    for w in range(24):
        c = pred_obj(X_t, w)
        # print(w, c)
        if c < best_cost: 
            best_cost = c
            best_w = w
            
    our = eval_decision(X_t, Y_t, best_w) + a*best_w

    r = np.random.randint(24)
    rand = eval_decision(X_t, Y_t, r) + a*r
    
    print("TRUE")
    best_cost = 1e5 
    best_dec = -1
    uniform_random = 0
    for w in range(24): 
        cur = eval_decision(X_t, Y_t, w) + a*w
        # print(w, cur)
        if cur < best_cost: 
            best_cost = cur 
            best_dec = w
        uniform_random += cur
        cur_costs.append(cur)
    all_costs.append(cur_costs)
    
    reward_loss = eval_decision(X_t, Y_t, reward_actions[indx]) 
    reward_losses.append(reward_loss)
    
    # if best_dec == 0: continue 
    
    optimal.append(best_cost)
    vanilla.append(e2e)    
    ours.append(our)
    random.append(uniform_random/24)
    two_stage.append(ts)
    
    print("CHOSEN  true cost:", best_w, our)
    print("RANDOM  true cost: ", -1, uniform_random/24)
    print("OPTIMAL true cost:", best_dec, best_cost)
    print("REWARDL true cost:", reward_actions[indx], reward_loss)
    print()
# Out:
# end-to-end cost: 0.2785796523094177
# 2-stage    cost: 0.4729428291320801
# TRUE
# CHOSEN  true cost: 5 0.18271511793136597
# RANDOM  true cost:  -1 0.2086476640154918
# OPTIMAL true cost: 2 0.17348530888557434
# REWARDL true cost: 2 0.17348530888557434
#
# end-to-end cost: 0.24664771556854248
# 2-stage    cost: 0.24551591277122498
# TRUE
# CHOSEN  true cost: 5 0.18453297019004822
# RANDOM  true cost:  -1 0.1976772683362166
# OPTIMAL true cost: 2 0.17139339447021484
# REWARDL true cost: 9 0.19339919090270996
#
# end-to-end cost: 0.3124611973762512
# 2-stage    cost: 0.37757569551467896
# TRUE
# CHOSEN  true cost: 2 0.23353350162506104
# RANDOM  true cost:  -1 0.2527272632966439
# OPTIMAL true cost: 15 0.2217484563589096
# REWARDL true cost: 1 0.23327240347862244
#
# end-to-end cost: 0.28278452157974243
# 2-stage    cost: 0.3346765637397766
# TRUE
# CHOSEN  true cost: 3 0.16561508178710938
# RANDOM  true cost:  -1 0.20395414407054582
# OPTIMAL true cost: 2 0.16439536213874817
# REWARDL true cost: 2 0.16439536213874817
#
# end-to-end cost: 0.3332255780696869
# 2-stage    cost: 1.4745182991027832
# TRUE
# CHOSEN  true cost: 5 0.2267495095729828
# RANDOM  true cost:  -1 0.25571062167485553
# OPTIMAL true cost: 1 0.21759413182735443
# REWARDL true cost: 2 0.21892809867858887
#
# end-to-end cost: 0.41778191924095154
# 2-stage    cost: 0.10048091411590576
# TRUE
# CHOSEN  true cost: 5 0.24222873151302338
# RANDOM  true cost:  -1 0.30222241890927154
# OPTIMAL true cost: 3 0.24122464656829834
# REWARDL true cost: 20 0.36747097969055176
#
# end-to-end cost: 0.24654611945152283
# 2-stage    cost: 6.018668174743652
# TRUE
# CHOSEN  true cost: 2 0.10354076325893402
# RANDOM  true cost:  -1 0.1734064385915796
# OPTIMAL true cost: 3 0.10273587703704834
# REWARDL true cost: 16 0.19541311264038086
#
# end-to-end cost: 0.19789913296699524
# 2-stage    cost: 2.27478289604187
# TRUE
# CHOSEN  true cost: 12 0.1598762422800064
# RANDOM  true cost:  -1 0.1583639234304428
# OPTIMAL true cost: 1 0.13036909699440002
# REWARDL true cost: 2 0.13178278505802155
#
# end-to-end cost: 0.2117302417755127
# 2-stage    cost: 2.8223156929016113
# TRUE
# CHOSEN  true cost: 12 0.210668683052063
# RANDOM  true cost:  -1 0.17472873628139496
# OPTIMAL true cost: 2 0.11477304995059967
# REWARDL true cost: 2 0.11477304995059967
#
# end-to-end cost: 0.6710430383682251
# 2-stage    cost: 2.5162270069122314
# TRUE
# CHOSEN  true cost: 23 0.6693851947784424
# RANDOM  true cost:  -1 0.5494011044502258
# OPTIMAL true cost: 5 0.16912496089935303
# REWARDL true cost: 2 0.2371029108762741
#
# end-to-end cost: 0.1817205250263214
# 2-stage    cost: 0.7741420269012451
# TRUE
# CHOSEN  true cost: 6 0.15437214076519012
# RANDOM  true cost:  -1 0.16712938621640205
# OPTIMAL true cost: 2 0.12799888849258423
# REWARDL true cost: 2 0.12799888849258423
#
# end-to-end cost: 0.1837897002696991
# 2-stage    cost: 3.844123363494873
# TRUE
# CHOSEN  true cost: 12 0.19390295445919037
# RANDOM  true cost:  -1 0.18609220845003924
# OPTIMAL true cost: 16 0.14593300223350525
# REWARDL true cost: 2 0.1932087391614914
#
# end-to-end cost: 0.2592626214027405
# 2-stage    cost: 0.2362159937620163
# TRUE
# CHOSEN  true cost: 14 0.19458679854869843
# RANDOM  true cost:  -1 0.22014474620421728
# OPTIMAL true cost: 15 0.1894073337316513
# REWARDL true cost: 2 0.20844373106956482
#
# end-to-end cost: 0.23191839456558228
# 2-stage    cost: 1.4995629787445068
# TRUE
# CHOSEN  true cost: 2 0.12254991382360458
# RANDOM  true cost:  -1 0.16395165802290043
# OPTIMAL true cost: 1 0.11980710923671722
# REWARDL true cost: 2 0.12254991382360458
#
# end-to-end cost: 0.19947533309459686
# 2-stage    cost: 3.6101531982421875
# TRUE
# CHOSEN  true cost: 12 0.15141883492469788
# RANDOM  true cost:  -1 0.16619926939407983
# OPTIMAL true cost: 15 0.13089948892593384
# REWARDL true cost: 1 0.168552964925766
#
# end-to-end cost: 0.2953798770904541
# 2-stage    cost: 2.977731704711914
# TRUE
# CHOSEN  true cost: 12 0.28337764739990234
# RANDOM  true cost:  -1 0.25392664099733037
# OPTIMAL true cost: 8 0.15281876921653748
# REWARDL true cost: 2 0.22681283950805664
#
# end-to-end cost: 0.1991148293018341
# 2-stage    cost: 0.2764590382575989
# TRUE
# CHOSEN  true cost: 12 0.17764970660209656
# RANDOM  true cost:  -1 0.16986361145973206
# OPTIMAL true cost: 15 0.144530788064003
# REWARDL true cost: 2 0.15222346782684326
#
# end-to-end cost: 0.2124553620815277
# 2-stage    cost: 0.8219403028488159
# TRUE
# CHOSEN  true cost: 12 0.17509141564369202
# RANDOM  true cost:  -1 0.17019019462168217
# OPTIMAL true cost: 1 0.14431171119213104
# REWARDL true cost: 2 0.14661018550395966
#
# end-to-end cost: 0.3330211639404297
# 2-stage    cost: 0.5989583730697632
# TRUE
# CHOSEN  true cost: 17 0.25590208172798157
# RANDOM  true cost:  -1 0.26698927270869416
# OPTIMAL true cost: 1 0.23852026462554932
# REWARDL true cost: 2 0.23964300751686096
#
# end-to-end cost: 0.3793611526489258
# 2-stage    cost: 1.4648187160491943
# TRUE
# CHOSEN  true cost: 8 0.241408109664917
# RANDOM  true cost:  -1 0.2767651391526063
# OPTIMAL true cost: 3 0.22634357213974
# REWARDL true cost: 2 0.22866639494895935
#
# end-to-end cost: 0.30847811698913574
# 2-stage    cost: 2.8778741359710693
# TRUE
# CHOSEN  true cost: 2 0.17665496468544006
# RANDOM  true cost:  -1 0.22462011687457561
# OPTIMAL true cost: 2 0.17665496468544006
# REWARDL true cost: 1 0.18313376605510712
#
# end-to-end cost: 0.2611112594604492
# 2-stage    cost: 1.257474660873413
# TRUE
# CHOSEN  true cost: 5 0.1577901542186737
# RANDOM  true cost:  -1 0.19035573986669382
# OPTIMAL true cost: 2 0.15006926655769348
# REWARDL true cost: 2 0.15006926655769348
#
# end-to-end cost: 0.23363201320171356
# 2-stage    cost: 1.649843454360962
# TRUE
# CHOSEN  true cost: 5 0.14980337023735046
# RANDOM  true cost:  -1 0.1746327430009842
# OPTIMAL true cost: 1 0.13607031106948853
# REWARDL true cost: 2 0.13834500312805176
#
# end-to-end cost: 0.23965582251548767
# 2-stage    cost: 1.08200204372406
# TRUE
# CHOSEN  true cost: 12 0.18120524287223816
# RANDOM  true cost:  -1 0.1816818304359913
# OPTIMAL true cost: 1 0.14760367572307587
# REWARDL true cost: 2 0.14845912158489227
#
# end-to-end cost: 0.2550164461135864
# 2-stage    cost: 0.6734888553619385
# TRUE
# CHOSEN  true cost: 12 0.19868192076683044
# RANDOM  true cost:  -1 0.19788364320993423
# OPTIMAL true cost: 1 0.1666373312473297
# REWARDL true cost: 2 0.16882100701332092
#
# end-to-end cost: 0.3314027786254883
# 2-stage    cost: 1.9601410627365112
# TRUE
# CHOSEN  true cost: 17 0.25488147139549255
# RANDOM  true cost:  -1 0.2539495627085368
# OPTIMAL true cost: 2 0.21739161014556885
# REWARDL true cost: 2 0.21739161014556885
#
# end-to-end cost: 0.3602292537689209
# 2-stage    cost: 0.8399301767349243
# TRUE
# CHOSEN  true cost: 5 0.23249715566635132
# RANDOM  true cost:  -1 0.2706788120170434
# OPTIMAL true cost: 3 0.22834360599517822
# REWARDL true cost: 2 0.22871963679790497
#
# end-to-end cost: 0.25401684641838074
# 2-stage    cost: 1.8639030456542969
# TRUE
# CHOSEN  true cost: 2 0.1329774707555771
# RANDOM  true cost:  -1 0.17940797470510006
# OPTIMAL true cost: 2 0.1329774707555771
# REWARDL true cost: 2 0.1329774707555771
#
# end-to-end cost: 0.2000538408756256
# 2-stage    cost: 4.457645893096924
# TRUE
# CHOSEN  true cost: 12 0.1520288586616516
# RANDOM  true cost:  -1 0.15062270872294903
# OPTIMAL true cost: 2 0.11823275685310364
# REWARDL true cost: 2 0.11823275685310364
#
# end-to-end cost: 0.2745324373245239
# 2-stage    cost: 0.6313725113868713
# TRUE
# CHOSEN  true cost: 12 0.2530371844768524
# RANDOM  true cost:  -1 0.23638475810488066
# OPTIMAL true cost: 8 0.16514547169208527
# REWARDL true cost: 2 0.22207936644554138
#
# end-to-end cost: 0.20613335072994232
# 2-stage    cost: 0.4429353177547455
# TRUE
# CHOSEN  true cost: 12 0.191024512052536
# RANDOM  true cost:  -1 0.1822653580456972
# OPTIMAL true cost: 1 0.1600291132926941
# REWARDL true cost: 2 0.16642853617668152
#
# end-to-end cost: 0.18299400806427002
# 2-stage    cost: 4.354650497436523
# TRUE
# CHOSEN  true cost: 12 0.14758579432964325
# RANDOM  true cost:  -1 0.14393220314135155
# OPTIMAL true cost: 1 0.11515714228153229
# REWARDL true cost: 2 0.11845415830612183
#
# end-to-end cost: 0.271848201751709
# 2-stage    cost: 0.9779108762741089
# TRUE
# CHOSEN  true cost: 17 0.2134089469909668
# RANDOM  true cost:  -1 0.24260839074850082
# OPTIMAL true cost: 16 0.2067474126815796
# REWARDL true cost: 20 0.24025794863700867
#
# end-to-end cost: 0.31932970881462097
# 2-stage    cost: 0.6658435463905334
# TRUE
# CHOSEN  true cost: 14 0.23012793064117432
# RANDOM  true cost:  -1 0.25291243754327297
# OPTIMAL true cost: 2 0.224487766623497
# REWARDL true cost: 2 0.224487766623497
#
# end-to-end cost: 0.22685687243938446
# 2-stage    cost: 4.8763651847839355
# TRUE
# CHOSEN  true cost: 2 0.11266276240348816
# RANDOM  true cost:  -1 0.15783081545184055
# OPTIMAL true cost: 2 0.11266276240348816
# REWARDL true cost: 1 0.1136433482170105
#
# end-to-end cost: 0.2563942074775696
# 2-stage    cost: 1.2000197172164917
# TRUE
# CHOSEN  true cost: 1 0.19359531998634338
# RANDOM  true cost:  -1 0.21766183028618494
# OPTIMAL true cost: 3 0.16676479578018188
# REWARDL true cost: 2 0.17425835132598877
#
# end-to-end cost: 0.23283648490905762
# 2-stage    cost: 0.03333570808172226
# TRUE
# CHOSEN  true cost: 12 0.1969936341047287
# RANDOM  true cost:  -1 0.1919681125630935
# OPTIMAL true cost: 15 0.16655199229717255
# REWARDL true cost: 2 0.1730322241783142
#
# end-to-end cost: 0.18912547826766968
# 2-stage    cost: 7.3639678955078125
# TRUE
# CHOSEN  true cost: 4 0.5478975772857666
# RANDOM  true cost:  -1 0.24380108000089726
# OPTIMAL true cost: 14 0.11862485110759735
# REWARDL true cost: 2 0.5731959939002991
#
# end-to-end cost: 0.2722361087799072
# 2-stage    cost: 0.8309323787689209
# TRUE
# CHOSEN  true cost: 12 0.2775276303291321
# RANDOM  true cost:  -1 0.23903565667569637
# OPTIMAL true cost: 1 0.18076476454734802
# REWARDL true cost: 2 0.18440914154052734
#
# end-to-end cost: 0.3231606185436249
# 2-stage    cost: 0.09064912796020508
# TRUE
# CHOSEN  true cost: 12 0.26710137724876404
# RANDOM  true cost:  -1 0.26827487411598366
# OPTIMAL true cost: 15 0.2405642867088318
# REWARDL true cost: 2 0.24887792766094208
#
# end-to-end cost: 0.40268513560295105
# 2-stage    cost: 0.11188918352127075
# TRUE
# CHOSEN  true cost: 2 0.25682345032691956
# RANDOM  true cost:  -1 0.3011767442027728
# OPTIMAL true cost: 3 0.25490015745162964
# REWARDL true cost: 1 0.26729634404182434
#
# end-to-end cost: 0.2779615819454193
# 2-stage    cost: 4.757762432098389
# TRUE
# CHOSEN  true cost: 2 0.11772283166646957
# RANDOM  true cost:  -1 0.18035854181895652
# OPTIMAL true cost: 3 0.11389763653278351
# REWARDL true cost: 20 0.2440354824066162
#
# end-to-end cost: 0.2491707056760788
# 2-stage    cost: 1.1771265268325806
# TRUE
# CHOSEN  true cost: 1 0.17489087581634521
# RANDOM  true cost:  -1 0.20177118418117365
# OPTIMAL true cost: 1 0.17489087581634521
# REWARDL true cost: 2 0.17671923339366913
#
# end-to-end cost: 0.23566482961177826
# 2-stage    cost: 0.5843426585197449
# TRUE
# CHOSEN  true cost: 12 0.18763330578804016
# RANDOM  true cost:  -1 0.1848655684540669
# OPTIMAL true cost: 1 0.15279532968997955
# REWARDL true cost: 2 0.15740399062633514
#
# end-to-end cost: 0.2060239315032959
# 2-stage    cost: 4.757522106170654
# TRUE
# CHOSEN  true cost: 12 0.14339551329612732
# RANDOM  true cost:  -1 0.1880877207343777
# OPTIMAL true cost: 1 0.10662572085857391
# REWARDL true cost: 1 0.10662572085857391
#
# end-to-end cost: 0.33965063095092773
# 2-stage    cost: 1.2266368865966797
# TRUE
# CHOSEN  true cost: 1 0.2640686333179474
# RANDOM  true cost:  -1 0.2910228557884693
# OPTIMAL true cost: 3 0.18146155774593353
# REWARDL true cost: 2 0.20709729194641113
#
# end-to-end cost: 0.2378939688205719
# 2-stage    cost: 3.4153928756713867
# TRUE
# CHOSEN  true cost: 12 0.20927290618419647
# RANDOM  true cost:  -1 0.2062033942590157
# OPTIMAL true cost: 15 0.18067821860313416
# REWARDL true cost: 2 0.19270972907543182
#
# end-to-end cost: 0.2033129334449768
# 2-stage    cost: 3.9462122917175293
# TRUE
# CHOSEN  true cost: 13 0.18118691444396973
# RANDOM  true cost:  -1 0.1817977304259936
# OPTIMAL true cost: 16 0.15377366542816162
# REWARDL true cost: 1 0.1605510115623474
#
# end-to-end cost: 0.25631147623062134
# 2-stage    cost: 5.811739921569824
# TRUE
# CHOSEN  true cost: 15 0.2410106062889099
# RANDOM  true cost:  -1 0.22486146353185177
# OPTIMAL true cost: 1 0.13656963407993317
# REWARDL true cost: 1 0.13656963407993317
#
# end-to-end cost: 0.26817017793655396
# 2-stage    cost: 0.45621681213378906
# TRUE
# CHOSEN  true cost: 15 0.2374027967453003
# RANDOM  true cost:  -1 0.23556803291042647
# OPTIMAL true cost: 2 0.1595713049173355
# REWARDL true cost: 2 0.1595713049173355
#
# end-to-end cost: 0.17079761624336243
# 2-stage    cost: 3.8764123916625977
# TRUE
# CHOSEN  true cost: 12 0.1673157662153244
# RANDOM  true cost:  -1 0.15284923867632946
# OPTIMAL true cost: 2 0.1199580654501915
# REWARDL true cost: 2 0.1199580654501915
#
# end-to-end cost: 0.3700014054775238
# 2-stage    cost: 3.2864084243774414
# TRUE
# CHOSEN  true cost: 12 0.4037819802761078
# RANDOM  true cost:  -1 0.31789430665473145
# OPTIMAL true cost: 2 0.12385988235473633
# REWARDL true cost: 2 0.12385988235473633
#
# end-to-end cost: 1.289278507232666
# 2-stage    cost: 1.3508628606796265
# TRUE
# CHOSEN  true cost: 22 1.2873855829238892
# RANDOM  true cost:  -1 1.0992426437636216
# OPTIMAL true cost: 3 0.3736277222633362
# REWARDL true cost: 2 0.42301058769226074
#
# end-to-end cost: 0.2200096845626831
# 2-stage    cost: 0.932792067527771
# TRUE
# CHOSEN  true cost: 12 0.22753112018108368
# RANDOM  true cost:  -1 0.21867982111871243
# OPTIMAL true cost: 16 0.18153786659240723
# REWARDL true cost: 2 0.21719138324260712
#
# end-to-end cost: 0.29937392473220825
# 2-stage    cost: 0.13117074966430664
# TRUE
# CHOSEN  true cost: 4 0.21565476059913635
# RANDOM  true cost:  -1 0.23493874383469424
# OPTIMAL true cost: 2 0.20918342471122742
# REWARDL true cost: 2 0.20918342471122742
#
# end-to-end cost: 0.19763660430908203
# 2-stage    cost: 5.2079267501831055
# TRUE
# CHOSEN  true cost: 2 0.1482127159833908
# RANDOM  true cost:  -1 0.1600971550991138
# OPTIMAL true cost: 15 0.13729289174079895
# REWARDL true cost: 1 0.1558551788330078
#
# end-to-end cost: 0.42680132389068604
# 2-stage    cost: 1.3631013631820679
# TRUE
# CHOSEN  true cost: 12 0.4477522373199463
# RANDOM  true cost:  -1 0.36019529464344185
# OPTIMAL true cost: 3 0.1796024888753891
# REWARDL true cost: 2 0.22728276252746582
#
# end-to-end cost: 0.19817796349525452
# 2-stage    cost: 0.17516648769378662
# TRUE
# CHOSEN  true cost: 12 0.18600589036941528
# RANDOM  true cost:  -1 0.17738295532763004
# OPTIMAL true cost: 16 0.14908789098262787
# REWARDL true cost: 1 0.18706505000591278
#
# end-to-end cost: 0.18159005045890808
# 2-stage    cost: 2.450226306915283
# TRUE
# CHOSEN  true cost: 4 0.14401938021183014
# RANDOM  true cost:  -1 0.14909401908516884
# OPTIMAL true cost: 2 0.12652704119682312
# REWARDL true cost: 2 0.12652704119682312
#
# end-to-end cost: 0.26369228959083557
# 2-stage    cost: 0.6051325798034668
# TRUE
# CHOSEN  true cost: 16 0.22232338786125183
# RANDOM  true cost:  -1 0.22746014843384424
# OPTIMAL true cost: 2 0.16747796535491943
# REWARDL true cost: 2 0.16747796535491943
#
# end-to-end cost: 0.2636580467224121
# 2-stage    cost: 0.7013790011405945
# TRUE
# CHOSEN  true cost: 16 0.20352785289287567
# RANDOM  true cost:  -1 0.24027645774185658
# OPTIMAL true cost: 16 0.20352785289287567
# REWARDL true cost: 2 0.2352564036846161
#
# end-to-end cost: 0.3071642220020294
# 2-stage    cost: 0.4709652066230774
# TRUE
# CHOSEN  true cost: 17 0.23795494437217712
# RANDOM  true cost:  -1 0.24795524589717388
# OPTIMAL true cost: 1 0.222458153963089
# REWARDL true cost: 2 0.22376057505607605
#
# end-to-end cost: 0.24324724078178406
# 2-stage    cost: 1.8243818283081055
# TRUE
# CHOSEN  true cost: 3 0.1439390927553177
# RANDOM  true cost:  -1 0.1793481589605411
# OPTIMAL true cost: 1 0.14109423756599426
# REWARDL true cost: 1 0.14109423756599426
#
# end-to-end cost: 0.24291512370109558
# 2-stage    cost: 0.3566964268684387
# TRUE
# CHOSEN  true cost: 1 0.17630553245544434
# RANDOM  true cost:  -1 0.20484023354947567
# OPTIMAL true cost: 1 0.17630553245544434
# REWARDL true cost: 2 0.18321244418621063
#
# end-to-end cost: 0.23284147679805756
# 2-stage    cost: 1.9331234693527222
# TRUE
# CHOSEN  true cost: 4 0.13832464814186096
# RANDOM  true cost:  -1 0.16754177398979664
# OPTIMAL true cost: 2 0.1299140751361847
# REWARDL true cost: 2 0.1299140751361847
#
# end-to-end cost: 0.19094614684581757
# 2-stage    cost: 5.059265613555908
# TRUE
# CHOSEN  true cost: 1 0.11574586480855942
# RANDOM  true cost:  -1 0.14902357508738837
# OPTIMAL true cost: 1 0.11574586480855942
# REWARDL true cost: 1 0.11574586480855942
#
# end-to-end cost: 0.4326937794685364
# 2-stage    cost: 1.7201836109161377
# TRUE
# CHOSEN  true cost: 12 0.44023364782333374
# RANDOM  true cost:  -1 0.377973052362601
# OPTIMAL true cost: 5 0.20729482173919678
# REWARDL true cost: 2 0.3218848705291748
#
# end-to-end cost: 0.2788756787776947
# 2-stage    cost: 0.8919198513031006
# TRUE
# CHOSEN  true cost: 12 0.24323724210262299
# RANDOM  true cost:  -1 0.24010868556797504
# OPTIMAL true cost: 15 0.20797789096832275
# REWARDL true cost: 2 0.2266608476638794
#
# end-to-end cost: 0.3996191918849945
# 2-stage    cost: 0.052190691232681274
# TRUE
# CHOSEN  true cost: 4 0.27744609117507935
# RANDOM  true cost:  -1 0.3078158472975095
# OPTIMAL true cost: 2 0.2704614996910095
# REWARDL true cost: 2 0.2704614996910095
#
# end-to-end cost: 0.3576996326446533
# 2-stage    cost: 0.025682348757982254
# TRUE
# CHOSEN  true cost: 5 0.19941148161888123
# RANDOM  true cost:  -1 0.25216805065671605
# OPTIMAL true cost: 3 0.19565489888191223
# REWARDL true cost: 1 0.2111225128173828
#
# end-to-end cost: 0.3303647041320801
# 2-stage    cost: 2.5919477939605713
# TRUE
# CHOSEN  true cost: 2 0.17068009078502655
# RANDOM  true cost:  -1 0.22629750395814577
# OPTIMAL true cost: 3 0.16710370779037476
# REWARDL true cost: 2 0.17068009078502655
#
# end-to-end cost: 0.333889901638031
# 2-stage    cost: 0.41649147868156433
# TRUE
# CHOSEN  true cost: 4 0.18203458189964294
# RANDOM  true cost:  -1 0.233704453955094
# OPTIMAL true cost: 3 0.1787836253643036
# REWARDL true cost: 2 0.1806967556476593
#
# end-to-end cost: 0.3270142078399658
# 2-stage    cost: 0.7106000185012817
# TRUE
# CHOSEN  true cost: 4 0.20293518900871277
# RANDOM  true cost:  -1 0.24062086331347624
# OPTIMAL true cost: 2 0.19553259015083313
# REWARDL true cost: 2 0.19553259015083313
#
# end-to-end cost: 0.3434438705444336
# 2-stage    cost: 0.2750324606895447
# TRUE
# CHOSEN  true cost: 4 0.21148543059825897
# RANDOM  true cost:  -1 0.2523707579821348
# OPTIMAL true cost: 3 0.206044539809227
# REWARDL true cost: 2 0.2065298855304718
#
# end-to-end cost: 0.4129502773284912
# 2-stage    cost: 1.4781923294067383
# TRUE
# CHOSEN  true cost: 8 0.2702535390853882
# RANDOM  true cost:  -1 0.30687547971804935
# OPTIMAL true cost: 3 0.25496017932891846
# REWARDL true cost: 2 0.25792577862739563
#
# end-to-end cost: 0.4497261643409729
# 2-stage    cost: 0.9716417193412781
# TRUE
# CHOSEN  true cost: 9 0.29117780923843384
# RANDOM  true cost:  -1 0.3290862701833248
# OPTIMAL true cost: 3 0.26714780926704407
# REWARDL true cost: 2 0.2747610807418823
#
# end-to-end cost: 0.3921937644481659
# 2-stage    cost: 0.2594318985939026
# TRUE
# CHOSEN  true cost: 5 0.24602770805358887
# RANDOM  true cost:  -1 0.292364027351141
# OPTIMAL true cost: 3 0.24227723479270935
# REWARDL true cost: 2 0.24423983693122864
#
# end-to-end cost: 0.35002875328063965
# 2-stage    cost: 2.3680942058563232
# TRUE
# CHOSEN  true cost: 4 0.16163025796413422
# RANDOM  true cost:  -1 0.23130471259355545
# OPTIMAL true cost: 3 0.15991221368312836
# REWARDL true cost: 1 0.18879005312919617
#
# end-to-end cost: 0.33634430170059204
# 2-stage    cost: 0.3143465518951416
# TRUE
# CHOSEN  true cost: 4 0.22117672860622406
# RANDOM  true cost:  -1 0.25623182269434136
# OPTIMAL true cost: 2 0.21432507038116455
# REWARDL true cost: 2 0.21432507038116455
#
# end-to-end cost: 0.32562923431396484
# 2-stage    cost: 0.6325951814651489
# TRUE
# CHOSEN  true cost: 4 0.20457850396633148
# RANDOM  true cost:  -1 0.24059005019565424
# OPTIMAL true cost: 3 0.19918930530548096
# REWARDL true cost: 2 0.19942204654216766
#
# end-to-end cost: 0.33478718996047974
# 2-stage    cost: 1.0276298522949219
# TRUE
# CHOSEN  true cost: 4 0.20388516783714294
# RANDOM  true cost:  -1 0.24749157143135866
# OPTIMAL true cost: 3 0.19949571788311005
# REWARDL true cost: 1 0.20768722891807556
#
# end-to-end cost: 0.4413003921508789
# 2-stage    cost: 0.38856396079063416
# TRUE
# CHOSEN  true cost: 8 0.28431013226509094
# RANDOM  true cost:  -1 0.3257804848253727
# OPTIMAL true cost: 3 0.2679414451122284
# REWARDL true cost: 2 0.27379053831100464
#
# end-to-end cost: 0.47359102964401245
# 2-stage    cost: 0.5222492218017578
# TRUE
# CHOSEN  true cost: 9 0.3052477538585663
# RANDOM  true cost:  -1 0.3439939779539903
# OPTIMAL true cost: 5 0.28092384338378906
# REWARDL true cost: 1 0.312033474445343
#
# end-to-end cost: 0.3640671670436859
# 2-stage    cost: 1.2392137050628662
# TRUE
# CHOSEN  true cost: 5 0.21156299114227295
# RANDOM  true cost:  -1 0.2620263323187828
# OPTIMAL true cost: 3 0.20642518997192383
# REWARDL true cost: 2 0.20899128913879395
#
# end-to-end cost: 0.34431135654449463
# 2-stage    cost: 0.37270352244377136
# TRUE
# CHOSEN  true cost: 4 0.20630083978176117
# RANDOM  true cost:  -1 0.25014686211943626
# OPTIMAL true cost: 3 0.2017628401517868
# REWARDL true cost: 2 0.20293918251991272
#
# end-to-end cost: 0.35280999541282654
# 2-stage    cost: 0.2595430314540863
# TRUE
# CHOSEN  true cost: 4 0.2040458619594574
# RANDOM  true cost:  -1 0.25445078189174336
# OPTIMAL true cost: 3 0.19901739060878754
# REWARDL true cost: 1 0.21121448278427124
#
# end-to-end cost: 0.34831926226615906
# 2-stage    cost: 1.9364694356918335
# TRUE
# CHOSEN  true cost: 4 0.17374210059642792
# RANDOM  true cost:  -1 0.23514981071154276
# OPTIMAL true cost: 3 0.16979442536830902
# REWARDL true cost: 2 0.17659053206443787
#
# end-to-end cost: 0.32887259125709534
# 2-stage    cost: 0.6337153315544128
# TRUE
# CHOSEN  true cost: 4 0.18649429082870483
# RANDOM  true cost:  -1 0.23578309329847494
# OPTIMAL true cost: 3 0.18211761116981506
# REWARDL true cost: 2 0.1837662160396576
#
# end-to-end cost: 0.36641496419906616
# 2-stage    cost: 2.7133471965789795
# TRUE
# CHOSEN  true cost: 8 0.26616668701171875
# RANDOM  true cost:  -1 0.2877120723327001
# OPTIMAL true cost: 2 0.249527245759964
# REWARDL true cost: 2 0.249527245759964
#
# end-to-end cost: 0.42777228355407715
# 2-stage    cost: 0.10079862177371979
# TRUE
# CHOSEN  true cost: 8 0.3107522130012512
# RANDOM  true cost:  -1 0.3341096378862858
# OPTIMAL true cost: 3 0.29557299613952637
# REWARDL true cost: 1 0.3014037609100342
#
# end-to-end cost: 0.3949741721153259
# 2-stage    cost: 0.021300820633769035
# TRUE
# CHOSEN  true cost: 3 0.20954257249832153
# RANDOM  true cost:  -1 0.2753528126825889
# OPTIMAL true cost: 3 0.20954257249832153
# REWARDL true cost: 2 0.2176271677017212
#
# end-to-end cost: 0.39314401149749756
# 2-stage    cost: 0.1094348356127739
# TRUE
# CHOSEN  true cost: 9 0.236572727560997
# RANDOM  true cost:  -1 0.2742844186723232
# OPTIMAL true cost: 3 0.20742103457450867
# REWARDL true cost: 2 0.21554462611675262
#
# end-to-end cost: 0.3972311019897461
# 2-stage    cost: 0.5454942584037781
# TRUE
# CHOSEN  true cost: 9 0.26422616839408875
# RANDOM  true cost:  -1 0.2890237725029389
# OPTIMAL true cost: 3 0.23424184322357178
# REWARDL true cost: 2 0.23782972991466522
#
# end-to-end cost: 0.4063778519630432
# 2-stage    cost: 0.3278219401836395
# TRUE
# CHOSEN  true cost: 9 0.24745844304561615
# RANDOM  true cost:  -1 0.28372943835953873
# OPTIMAL true cost: 3 0.21950308978557587
# REWARDL true cost: 2 0.22793148458003998
#
# end-to-end cost: 0.4708736836910248
# 2-stage    cost: 0.06490162760019302
# TRUE
# CHOSEN  true cost: 9 0.27776405215263367
# RANDOM  true cost:  -1 0.3299667735894521
# OPTIMAL true cost: 5 0.2534869313240051
# REWARDL true cost: 2 0.27083441615104675
#
# end-to-end cost: 0.527658224105835
# 2-stage    cost: 1.2050883769989014
# TRUE
# CHOSEN  true cost: 9 0.32897958159446716
# RANDOM  true cost:  -1 0.38165269419550896
# OPTIMAL true cost: 5 0.3055855631828308
# REWARDL true cost: 1 0.35746443271636963
#
# end-to-end cost: 0.5786481499671936
# 2-stage    cost: 0.05449714884161949
# TRUE
# CHOSEN  true cost: 9 0.38300570845603943
# RANDOM  true cost:  -1 0.4317799073954423
# OPTIMAL true cost: 5 0.36137068271636963
# REWARDL true cost: 1 0.41075682640075684
#
# end-to-end cost: 0.4728682041168213
# 2-stage    cost: 0.7040164470672607
# TRUE
# CHOSEN  true cost: 5 0.24824008345603943
# RANDOM  true cost:  -1 0.33007632941007614
# OPTIMAL true cost: 5 0.24824008345603943
# REWARDL true cost: 2 0.26751789450645447
#
# end-to-end cost: 0.44347840547561646
# 2-stage    cost: 0.06838535517454147
# TRUE
# CHOSEN  true cost: 8 0.2458324283361435
# RANDOM  true cost:  -1 0.31011143513023853
# OPTIMAL true cost: 5 0.2331635057926178
# REWARDL true cost: 2 0.24851040542125702
#
# end-to-end cost: 0.4111096262931824
# 2-stage    cost: 1.4241747856140137
# TRUE
# CHOSEN  true cost: 9 0.22692212462425232
# RANDOM  true cost:  -1 0.27867662099500495
# OPTIMAL true cost: 5 0.19893698394298553
# REWARDL true cost: 2 0.21446236968040466
#
# end-to-end cost: 0.3997079133987427
# 2-stage    cost: 0.7874547839164734
# TRUE
# CHOSEN  true cost: 9 0.23027417063713074
# RANDOM  true cost:  -1 0.27688377412656945
# OPTIMAL true cost: 5 0.20397210121154785
# REWARDL true cost: 2 0.21481752395629883
#
# end-to-end cost: 0.4144287705421448
# 2-stage    cost: 0.2710530757904053
# TRUE
# CHOSEN  true cost: 2 0.2301887720823288
# RANDOM  true cost:  -1 0.2924047938237588
# OPTIMAL true cost: 5 0.21960866451263428
# REWARDL true cost: 2 0.2301887720823288
#
# end-to-end cost: 0.543700635433197
# 2-stage    cost: 0.0668894425034523
# TRUE
# CHOSEN  true cost: 9 0.34303390979766846
# RANDOM  true cost:  -1 0.395575159539779
# OPTIMAL true cost: 5 0.3211909532546997
# REWARDL true cost: 2 0.3395894765853882
#
# end-to-end cost: 0.5746139287948608
# 2-stage    cost: 0.03333327919244766
# TRUE
# CHOSEN  true cost: 6 0.34607887268066406
# RANDOM  true cost:  -1 0.42018770426511765
# OPTIMAL true cost: 5 0.34188103675842285
# REWARDL true cost: 1 0.4059257507324219
#
# end-to-end cost: 0.4571246802806854
# 2-stage    cost: 1.5791869163513184
# TRUE
# CHOSEN  true cost: 5 0.22427086532115936
# RANDOM  true cost:  -1 0.3148750265439351
# OPTIMAL true cost: 5 0.22427086532115936
# REWARDL true cost: 1 0.2891056537628174
#
# end-to-end cost: 0.44379276037216187
# 2-stage    cost: 0.0635894164443016
# TRUE
# CHOSEN  true cost: 2 0.2651178240776062
# RANDOM  true cost:  -1 0.32279014587402344
# OPTIMAL true cost: 4 0.25478172302246094
# REWARDL true cost: 2 0.2651178240776062
#
# end-to-end cost: 0.4181995987892151
# 2-stage    cost: 0.4642919898033142
# TRUE
# CHOSEN  true cost: 9 0.2443312406539917
# RANDOM  true cost:  -1 0.2887260081867377
# OPTIMAL true cost: 5 0.215021014213562
# REWARDL true cost: 1 0.25355228781700134
#
# end-to-end cost: 0.4204229712486267
# 2-stage    cost: 0.01544362585991621
# TRUE
# CHOSEN  true cost: 9 0.24590937793254852
# RANDOM  true cost:  -1 0.2919241587320964
# OPTIMAL true cost: 5 0.21827709674835205
# REWARDL true cost: 2 0.23054024577140808
#
# end-to-end cost: 0.4227299392223358
# 2-stage    cost: 0.11073374003171921
# TRUE
# CHOSEN  true cost: 2 0.23990750312805176
# RANDOM  true cost:  -1 0.2997419635454814
# OPTIMAL true cost: 5 0.23009145259857178
# REWARDL true cost: 1 0.26117241382598877
#
# end-to-end cost: 0.5195169448852539
# 2-stage    cost: 0.26823529601097107
# TRUE
# CHOSEN  true cost: 8 0.313888281583786
# RANDOM  true cost:  -1 0.3754749459524949
# OPTIMAL true cost: 5 0.2986324727535248
# REWARDL true cost: 1 0.35062742233276367
#
# end-to-end cost: 0.5721720457077026
# 2-stage    cost: 0.05192626640200615
# TRUE
# CHOSEN  true cost: 5 0.3405079245567322
# RANDOM  true cost:  -1 0.4202974997460842
# OPTIMAL true cost: 5 0.3405079245567322
# REWARDL true cost: 1 0.40306568145751953
#
# end-to-end cost: 0.47276920080184937
# 2-stage    cost: 0.18130747973918915
# TRUE
# CHOSEN  true cost: 5 0.23869073390960693
# RANDOM  true cost:  -1 0.32910278501609963
# OPTIMAL true cost: 5 0.23869073390960693
# REWARDL true cost: 2 0.2621031701564789
#
# end-to-end cost: 0.4533321261405945
# 2-stage    cost: 0.041269320994615555
# TRUE
# CHOSEN  true cost: 2 0.2629489004611969
# RANDOM  true cost:  -1 0.323841933781902
# OPTIMAL true cost: 5 0.24838685989379883
# REWARDL true cost: 2 0.2629489004611969
#
# end-to-end cost: 0.41373997926712036
# 2-stage    cost: 0.27713343501091003
# TRUE
# CHOSEN  true cost: 9 0.2434018850326538
# RANDOM  true cost:  -1 0.28881815696756047
# OPTIMAL true cost: 5 0.21470992267131805
# REWARDL true cost: 2 0.2256554365158081
#
# end-to-end cost: 0.3747287392616272
# 2-stage    cost: 0.5968602895736694
# TRUE
# CHOSEN  true cost: 5 0.20545361936092377
# RANDOM  true cost:  -1 0.2651139199733734
# OPTIMAL true cost: 3 0.20224593579769135
# REWARDL true cost: 1 0.22341738641262054
#
# end-to-end cost: 0.4008863568305969
# 2-stage    cost: 0.3850846290588379
# TRUE
# CHOSEN  true cost: 4 0.2403811663389206
# RANDOM  true cost:  -1 0.29166459913055104
# OPTIMAL true cost: 3 0.23533760011196136
# REWARDL true cost: 2 0.23959603905677795
#
# end-to-end cost: 0.5054662823677063
# 2-stage    cost: 0.242801234126091
# TRUE
# CHOSEN  true cost: 8 0.3224673569202423
# RANDOM  true cost:  -1 0.37361545736591023
# OPTIMAL true cost: 5 0.30723628401756287
# REWARDL true cost: 2 0.318553626537323
#
# end-to-end cost: 0.5739083886146545
# 2-stage    cost: 0.05083916708827019
# TRUE
# CHOSEN  true cost: 9 0.3791773319244385
# RANDOM  true cost:  -1 0.4264778904616833
# OPTIMAL true cost: 5 0.3575149476528168
# REWARDL true cost: 1 0.4057675004005432
#
# end-to-end cost: 0.48521727323532104
# 2-stage    cost: 0.10491849482059479
# TRUE
# CHOSEN  true cost: 8 0.27377307415008545
# RANDOM  true cost:  -1 0.34579037750760716
# OPTIMAL true cost: 5 0.2577172517776489
# REWARDL true cost: 1 0.315441757440567
#
# end-to-end cost: 0.4625370502471924
# 2-stage    cost: 1.8005436658859253
# TRUE
# CHOSEN  true cost: 2 0.30018824338912964
# RANDOM  true cost:  -1 0.35105425119400024
# OPTIMAL true cost: 4 0.2934796214103699
# REWARDL true cost: 2 0.30018824338912964
#
# end-to-end cost: 0.4366629123687744
# 2-stage    cost: 0.019388902932405472
# TRUE
# CHOSEN  true cost: 9 0.26046884059906006
# RANDOM  true cost:  -1 0.3068994265049696
# OPTIMAL true cost: 5 0.2329612821340561
# REWARDL true cost: 2 0.24555447697639465
#
# end-to-end cost: 0.4280102252960205
# 2-stage    cost: 0.04729921743273735
# TRUE
# CHOSEN  true cost: 9 0.25782689452171326
# RANDOM  true cost:  -1 0.3020584210753441
# OPTIMAL true cost: 5 0.2308710813522339
# REWARDL true cost: 2 0.24294941127300262
#
# end-to-end cost: 0.4343506991863251
# 2-stage    cost: 0.05683683976531029
# TRUE
# CHOSEN  true cost: 2 0.24600329995155334
# RANDOM  true cost:  -1 0.30628302941719693
# OPTIMAL true cost: 5 0.23451828956604004
# REWARDL true cost: 1 0.2705352008342743
#
# end-to-end cost: 0.5235841274261475
# 2-stage    cost: 0.018285399302840233
# TRUE
# CHOSEN  true cost: 8 0.32989999651908875
# RANDOM  true cost:  -1 0.3854602525631587
# OPTIMAL true cost: 5 0.31431013345718384
# REWARDL true cost: 2 0.32915836572647095
#
# end-to-end cost: 0.5447646379470825
# 2-stage    cost: 0.027363836765289307
# TRUE
# CHOSEN  true cost: 5 0.3167344927787781
# RANDOM  true cost:  -1 0.39592713862657547
# OPTIMAL true cost: 5 0.3167344927787781
# REWARDL true cost: 1 0.3744872510433197
#
# end-to-end cost: 0.42298004031181335
# 2-stage    cost: 1.2286943197250366
# TRUE
# CHOSEN  true cost: 5 0.2120112031698227
# RANDOM  true cost:  -1 0.29533488613863784
# OPTIMAL true cost: 5 0.2120112031698227
# REWARDL true cost: 12 0.2654913067817688
#
# end-to-end cost: 0.35946986079216003
# 2-stage    cost: 0.11563645303249359
# TRUE
# CHOSEN  true cost: 5 0.19790279865264893
# RANDOM  true cost:  -1 0.25785268905262154
# OPTIMAL true cost: 3 0.19649457931518555
# REWARDL true cost: 2 0.2005346268415451
#
# end-to-end cost: 0.31539925932884216
# 2-stage    cost: 2.5754177570343018
# TRUE
# CHOSEN  true cost: 4 0.1640447974205017
# RANDOM  true cost:  -1 0.22418956893185774
# OPTIMAL true cost: 3 0.1626112163066864
# REWARDL true cost: 2 0.16548526287078857
#
# end-to-end cost: 0.2696562707424164
# 2-stage    cost: 1.5445144176483154
# TRUE
# CHOSEN  true cost: 4 0.15532773733139038
# RANDOM  true cost:  -1 0.2026356142014265
# OPTIMAL true cost: 3 0.15386340022087097
# REWARDL true cost: 2 0.15546907484531403
#
# end-to-end cost: 0.2253584861755371
# 2-stage    cost: 2.9285454750061035
# TRUE
# CHOSEN  true cost: 4 0.11741497367620468
# RANDOM  true cost:  -1 0.16483402469505867
# OPTIMAL true cost: 3 0.11636777222156525
# REWARDL true cost: 2 0.11705650389194489
#
# end-to-end cost: 0.2522463798522949
# 2-stage    cost: 2.5982279777526855
# TRUE
# CHOSEN  true cost: 8 0.18119323253631592
# RANDOM  true cost:  -1 0.20784678310155869
# OPTIMAL true cost: 2 0.17736533284187317
# REWARDL true cost: 2 0.17736533284187317
#
# end-to-end cost: 0.24546030163764954
# 2-stage    cost: 1.207298755645752
# TRUE
# CHOSEN  true cost: 4 0.18327364325523376
# RANDOM  true cost:  -1 0.20652120932936668
# OPTIMAL true cost: 2 0.18063829839229584
# REWARDL true cost: 2 0.18063829839229584
#
# end-to-end cost: 0.12712332606315613
# 2-stage    cost: 3.8672122955322266
# TRUE
# CHOSEN  true cost: 1 0.3684714734554291
# RANDOM  true cost:  -1 0.3024612969408433
# OPTIMAL true cost: 0 0.12712332606315613
# REWARDL true cost: 1 0.3684714734554291
#
# end-to-end cost: 0.25764188170433044
# 2-stage    cost: 0.12811627984046936
# TRUE
# CHOSEN  true cost: 8 0.20407912135124207
# RANDOM  true cost:  -1 0.21812182975312075
# OPTIMAL true cost: 2 0.19733530282974243
# REWARDL true cost: 14 0.2097492665052414
#
# end-to-end cost: 0.3984343409538269
# 2-stage    cost: 0.03544829040765762
# TRUE
# CHOSEN  true cost: 4 0.21088439226150513
# RANDOM  true cost:  -1 0.277146032700936
# OPTIMAL true cost: 5 0.21075032651424408
# REWARDL true cost: 2 0.22002911567687988
#
# end-to-end cost: 0.4105653166770935
# 2-stage    cost: 0.4662938714027405
# TRUE
# CHOSEN  true cost: 2 0.22679591178894043
# RANDOM  true cost:  -1 0.2869152308752139
# OPTIMAL true cost: 5 0.21676139533519745
# REWARDL true cost: 1 0.24858275055885315
#
# end-to-end cost: 0.3750764727592468
# 2-stage    cost: 2.2360849380493164
# TRUE
# CHOSEN  true cost: 4 0.18464791774749756
# RANDOM  true cost:  -1 0.25910115987062454
# OPTIMAL true cost: 5 0.1841973513364792
# REWARDL true cost: 2 0.19420509040355682
#
# end-to-end cost: 0.4089381694793701
# 2-stage    cost: 0.6737717390060425
# TRUE
# CHOSEN  true cost: 8 0.2753588557243347
# RANDOM  true cost:  -1 0.3159980736672878
# OPTIMAL true cost: 3 0.26320454478263855
# REWARDL true cost: 2 0.26571017503738403
#
# end-to-end cost: 0.3747815489768982
# 2-stage    cost: 3.537600040435791
# TRUE
# CHOSEN  true cost: 5 0.2220737189054489
# RANDOM  true cost:  -1 0.2769073657691479
# OPTIMAL true cost: 3 0.22146587073802948
# REWARDL true cost: 1 0.23988032341003418
#
# end-to-end cost: 0.2061471939086914
# 2-stage    cost: 2.463656425476074
# TRUE
# CHOSEN  true cost: 4 0.1248052567243576
# RANDOM  true cost:  -1 0.1644058208912611
# OPTIMAL true cost: 2 0.12129712104797363
# REWARDL true cost: 1 0.12297157943248749
#
# end-to-end cost: 0.25227177143096924
# 2-stage    cost: 1.201874017715454
# TRUE
# CHOSEN  true cost: 2 0.16689035296440125
# RANDOM  true cost:  -1 0.20262906638284525
# OPTIMAL true cost: 2 0.16689035296440125
# REWARDL true cost: 1 0.16725963354110718
#
# end-to-end cost: 0.3561848998069763
# 2-stage    cost: 0.8538222312927246
# TRUE
# CHOSEN  true cost: 4 0.19505801796913147
# RANDOM  true cost:  -1 0.2512657642364502
# OPTIMAL true cost: 3 0.19224326312541962
# REWARDL true cost: 2 0.19624000787734985
#
# end-to-end cost: 0.3903031349182129
# 2-stage    cost: 0.45720022916793823
# TRUE
# CHOSEN  true cost: 5 0.21205908060073853
# RANDOM  true cost:  -1 0.27652485854923725
# OPTIMAL true cost: 3 0.2112509310245514
# REWARDL true cost: 2 0.21834585070610046
#
# end-to-end cost: 0.4013698101043701
# 2-stage    cost: 0.5472469329833984
# TRUE
# CHOSEN  true cost: 5 0.22157126665115356
# RANDOM  true cost:  -1 0.2850753242770831
# OPTIMAL true cost: 3 0.21980856359004974
# REWARDL true cost: 2 0.2272815704345703
#
# end-to-end cost: 0.49676331877708435
# 2-stage    cost: 0.21042823791503906
# TRUE
# CHOSEN  true cost: 8 0.31716203689575195
# RANDOM  true cost:  -1 0.3669157649079959
# OPTIMAL true cost: 5 0.3014126718044281
# REWARDL true cost: 2 0.312548965215683
#
# end-to-end cost: 0.5037450790405273
# 2-stage    cost: 0.14439481496810913
# TRUE
# CHOSEN  true cost: 5 0.2924511432647705
# RANDOM  true cost:  -1 0.36706246559818584
# OPTIMAL true cost: 5 0.2924511432647705
# REWARDL true cost: 2 0.307919442653656
#
# end-to-end cost: 0.37500959634780884
# 2-stage    cost: 4.863796234130859
# TRUE
# CHOSEN  true cost: 5 0.19031453132629395
# RANDOM  true cost:  -1 0.2643038022021453
# OPTIMAL true cost: 5 0.19031453132629395
# REWARDL true cost: 2 0.1989414393901825
#
# end-to-end cost: 0.2331020087003708
# 2-stage    cost: 0.18897029757499695
# TRUE
# CHOSEN  true cost: 4 0.16331011056900024
# RANDOM  true cost:  -1 0.1891516800969839
# OPTIMAL true cost: 1 0.15759488940238953
# REWARDL true cost: 2 0.15783065557479858
#
# end-to-end cost: 0.2098623365163803
# 2-stage    cost: 0.19931988418102264
# TRUE
# CHOSEN  true cost: 1 0.14908212423324585
# RANDOM  true cost:  -1 0.17399044459064802
# OPTIMAL true cost: 2 0.14787167310714722
# REWARDL true cost: 2 0.14787167310714722
#
# end-to-end cost: 0.2078210562467575
# 2-stage    cost: 0.538503885269165
# TRUE
# CHOSEN  true cost: 1 0.14121147990226746
# RANDOM  true cost:  -1 0.17086630625029406
# OPTIMAL true cost: 2 0.13899250328540802
# REWARDL true cost: 2 0.13899250328540802
#
# end-to-end cost: 0.19984392821788788
# 2-stage    cost: 2.4852452278137207
# TRUE
# CHOSEN  true cost: 2 0.10619192570447922
# RANDOM  true cost:  -1 0.15230209877093634
# OPTIMAL true cost: 3 0.1058843582868576
# REWARDL true cost: 2 0.10619192570447922
#
# end-to-end cost: 0.27047020196914673
# 2-stage    cost: 2.132453680038452
# TRUE
# CHOSEN  true cost: 5 0.21053224802017212
# RANDOM  true cost:  -1 0.234813146914045
# OPTIMAL true cost: 2 0.20515088737010956
# REWARDL true cost: 2 0.20515088737010956
#
# end-to-end cost: 0.29622364044189453
# 2-stage    cost: 1.8679325580596924
# TRUE
# CHOSEN  true cost: 4 0.21500229835510254
# RANDOM  true cost:  -1 0.2466559335589409
# OPTIMAL true cost: 2 0.2117748260498047
# REWARDL true cost: 2 0.2117748260498047
#
# end-to-end cost: 0.38529837131500244
# 2-stage    cost: 0.15608049929141998
# TRUE
# CHOSEN  true cost: 4 0.27752289175987244
# RANDOM  true cost:  -1 0.3105418731768926
# OPTIMAL true cost: 5 0.2765505313873291
# REWARDL true cost: 2 0.28013890981674194
#
# end-to-end cost: 0.38797956705093384
# 2-stage    cost: 0.8567140102386475
# TRUE
# CHOSEN  true cost: 5 0.2089991420507431
# RANDOM  true cost:  -1 0.2739095923801263
# OPTIMAL true cost: 3 0.20779570937156677
# REWARDL true cost: 2 0.21501687169075012
#
# end-to-end cost: 0.3737413287162781
# 2-stage    cost: 0.6055383682250977
# TRUE
# CHOSEN  true cost: 5 0.195155069231987
# RANDOM  true cost:  -1 0.2617710952957471
# OPTIMAL true cost: 3 0.19408738613128662
# REWARDL true cost: 2 0.2012145221233368
#
# end-to-end cost: 0.32439273595809937
# 2-stage    cost: 2.8288073539733887
# TRUE
# CHOSEN  true cost: 5 0.15737435221672058
# RANDOM  true cost:  -1 0.22383574955165386
# OPTIMAL true cost: 3 0.15526023507118225
# REWARDL true cost: 2 0.16028867661952972
#
# end-to-end cost: 0.28304535150527954
# 2-stage    cost: 1.5138025283813477
# TRUE
# CHOSEN  true cost: 5 0.16218459606170654
# RANDOM  true cost:  -1 0.21342342967788377
# OPTIMAL true cost: 3 0.16133329272270203
# REWARDL true cost: 2 0.16273586452007294
#
# end-to-end cost: 0.3983933925628662
# 2-stage    cost: 0.1257489174604416
# TRUE
# CHOSEN  true cost: 5 0.28226786851882935
# RANDOM  true cost:  -1 0.3185586283604304
# OPTIMAL true cost: 3 0.2820340394973755
# REWARDL true cost: 2 0.2833425998687744
#
# end-to-end cost: 0.3725273013114929
# 2-stage    cost: 4.082212924957275
# TRUE
# CHOSEN  true cost: 3 0.19944751262664795
# RANDOM  true cost:  -1 0.2872297540307045
# OPTIMAL true cost: 4 0.1989634931087494
# REWARDL true cost: 2 0.20557177066802979
#
# end-to-end cost: 0.21475771069526672
# 2-stage    cost: 1.433518648147583
# TRUE
# CHOSEN  true cost: 5 0.16388466954231262
# RANDOM  true cost:  -1 0.18542649038136005
# OPTIMAL true cost: 2 0.1559431254863739
# REWARDL true cost: 1 0.15765923261642456
#
# end-to-end cost: 0.2694494426250458
# 2-stage    cost: 0.4934059977531433
# TRUE
# CHOSEN  true cost: 2 0.15737508237361908
# RANDOM  true cost:  -1 0.19991649749378362
# OPTIMAL true cost: 2 0.15737508237361908
# REWARDL true cost: 1 0.16102908551692963
#
# end-to-end cost: 0.20939287543296814
# 2-stage    cost: 7.412487030029297
# TRUE
# CHOSEN  true cost: 4 0.2147166132926941
# RANDOM  true cost:  -1 0.2467028678705295
# OPTIMAL true cost: 1 0.1096479743719101
# REWARDL true cost: 2 0.15493261814117432
#
# end-to-end cost: 0.1677791327238083
# 2-stage    cost: 6.756974220275879
# TRUE
# CHOSEN  true cost: 1 0.10854339599609375
# RANDOM  true cost:  -1 0.1012507878864805
# OPTIMAL true cost: 3 0.07275325059890747
# REWARDL true cost: 2 0.08422815799713135
#
# end-to-end cost: 0.10809441655874252
# 2-stage    cost: 1.8616336584091187
# TRUE
# CHOSEN  true cost: 22 0.12394645065069199
# RANDOM  true cost:  -1 0.150676678866148
# OPTIMAL true cost: 0 0.10809441655874252
# REWARDL true cost: 2 0.1506718397140503
#
# end-to-end cost: 0.1927793025970459
# 2-stage    cost: 4.91916036605835
# TRUE
# CHOSEN  true cost: 12 0.186079740524292
# RANDOM  true cost:  -1 0.1835752030213674
# OPTIMAL true cost: 15 0.17169849574565887
# REWARDL true cost: 2 0.17446133494377136
#
# end-to-end cost: 0.21003805100917816
# 2-stage    cost: 2.672502040863037
# TRUE
# CHOSEN  true cost: 4 0.16320082545280457
# RANDOM  true cost:  -1 0.1774434900532166
# OPTIMAL true cost: 1 0.15447361767292023
# REWARDL true cost: 2 0.15640532970428467
#
# end-to-end cost: 0.10349752753973007
# 2-stage    cost: 4.929582595825195
# TRUE
# CHOSEN  true cost: 1 0.4705623388290405
# RANDOM  true cost:  -1 0.2985704398403565
# OPTIMAL true cost: 0 0.10349752753973007
# REWARDL true cost: 2 0.5109339356422424
#
# end-to-end cost: 0.1392544060945511
# 2-stage    cost: 0.1874781847000122
# TRUE
# CHOSEN  true cost: 22 0.1437155306339264
# RANDOM  true cost:  -1 0.1490762811154127
# OPTIMAL true cost: 1 0.1347486972808838
# REWARDL true cost: 2 0.14095821976661682
#
# end-to-end cost: 0.2671549916267395
# 2-stage    cost: 0.07151108980178833
# TRUE
# CHOSEN  true cost: 2 0.20186418294906616
# RANDOM  true cost:  -1 0.2236806390186151
# OPTIMAL true cost: 2 0.20186418294906616
# REWARDL true cost: 2 0.20186418294906616
#
# end-to-end cost: 0.18540871143341064
# 2-stage    cost: 7.45372200012207
# TRUE
# CHOSEN  true cost: 4 0.09797914326190948
# RANDOM  true cost:  -1 0.13928117820372185
# OPTIMAL true cost: 2 0.09392209351062775
# REWARDL true cost: 2 0.09392209351062775
#
# end-to-end cost: 0.22395500540733337
# 2-stage    cost: 0.13517647981643677
# TRUE
# CHOSEN  true cost: 2 0.1753295511007309
# RANDOM  true cost:  -1 0.1956970685472091
# OPTIMAL true cost: 2 0.1753295511007309
# REWARDL true cost: 2 0.1753295511007309
#
# end-to-end cost: 0.32164227962493896
# 2-stage    cost: 4.052934646606445
# TRUE
# CHOSEN  true cost: 5 0.21165525913238525
# RANDOM  true cost:  -1 0.24890327888230482
# OPTIMAL true cost: 2 0.20795148611068726
# REWARDL true cost: 2 0.20795148611068726
#
# end-to-end cost: 0.273344486951828
# 2-stage    cost: 7.562617301940918
# TRUE
# CHOSEN  true cost: 4 0.16885578632354736
# RANDOM  true cost:  -1 0.20817242190241814
# OPTIMAL true cost: 2 0.165109783411026
# REWARDL true cost: 2 0.165109783411026
#
# end-to-end cost: 0.1405823677778244
# 2-stage    cost: 3.403209686279297
# TRUE
# CHOSEN  true cost: 1 0.10177048295736313
# RANDOM  true cost:  -1 0.1289697882408897
# OPTIMAL true cost: 1 0.10177048295736313
# REWARDL true cost: 2 0.10216446220874786
#
# end-to-end cost: 0.12733401358127594
# 2-stage    cost: 1.7185828685760498
# TRUE
# CHOSEN  true cost: 22 0.13441303372383118
# RANDOM  true cost:  -1 0.16108113154768944
# OPTIMAL true cost: 0 0.12733401358127594
# REWARDL true cost: 2 0.16446448862552643
#
# end-to-end cost: 0.20871064066886902
# 2-stage    cost: 1.787212610244751
# TRUE
# CHOSEN  true cost: 12 0.17545875906944275
# RANDOM  true cost:  -1 0.1756253701945146
# OPTIMAL true cost: 1 0.1470099836587906
# REWARDL true cost: 2 0.14712676405906677
#
# end-to-end cost: 0.2722330093383789
# 2-stage    cost: 0.21308737993240356
# TRUE
# CHOSEN  true cost: 2 0.19954437017440796
# RANDOM  true cost:  -1 0.22701664827764034
# OPTIMAL true cost: 2 0.19954437017440796
# REWARDL true cost: 2 0.19954437017440796
#
# end-to-end cost: 0.2620229125022888
# 2-stage    cost: 3.44693660736084
# TRUE
# CHOSEN  true cost: 4 0.15704181790351868
# RANDOM  true cost:  -1 0.1992546965678533
# OPTIMAL true cost: 2 0.1536511331796646
# REWARDL true cost: 2 0.1536511331796646
#
# end-to-end cost: 0.36683541536331177
# 2-stage    cost: 0.10815411806106567
# TRUE
# CHOSEN  true cost: 8 0.29313910007476807
# RANDOM  true cost:  -1 0.3086590903500716
# OPTIMAL true cost: 2 0.2875404357910156
# REWARDL true cost: 2 0.2875404357910156
#
# end-to-end cost: 0.44923946261405945
# 2-stage    cost: 0.06618303805589676
# TRUE
# CHOSEN  true cost: 5 0.3007243871688843
# RANDOM  true cost:  -1 0.34691282734274864
# OPTIMAL true cost: 3 0.3004169464111328
# REWARDL true cost: 1 0.31506964564323425
#
# end-to-end cost: 0.3844781816005707
# 2-stage    cost: 1.2637362480163574
# TRUE
# CHOSEN  true cost: 5 0.1833731234073639
# RANDOM  true cost:  -1 0.26335369423031807
# OPTIMAL true cost: 5 0.1833731234073639
# REWARDL true cost: 1 0.21999725699424744
#
# end-to-end cost: 0.33333954215049744
# 2-stage    cost: 1.2611503601074219
# TRUE
# CHOSEN  true cost: 5 0.17892609536647797
# RANDOM  true cost:  -1 0.24071107928951582
# OPTIMAL true cost: 3 0.17681118845939636
# REWARDL true cost: 2 0.1798904836177826
#
# end-to-end cost: 0.32205361127853394
# 2-stage    cost: 0.8343883752822876
# TRUE
# CHOSEN  true cost: 5 0.17930415272712708
# RANDOM  true cost:  -1 0.2328745579967896
# OPTIMAL true cost: 3 0.17799663543701172
# REWARDL true cost: 2 0.18040186166763306
#
# end-to-end cost: 0.31297582387924194
# 2-stage    cost: 0.31868815422058105
# TRUE
# CHOSEN  true cost: 5 0.18832789361476898
# RANDOM  true cost:  -1 0.23652302535871664
# OPTIMAL true cost: 3 0.1876668930053711
# REWARDL true cost: 2 0.18900594115257263
#
# end-to-end cost: 0.33789366483688354
# 2-stage    cost: 0.8614383935928345
# TRUE
# CHOSEN  true cost: 6 0.21769897639751434
# RANDOM  true cost:  -1 0.25947530133028823
# OPTIMAL true cost: 3 0.21268388628959656
# REWARDL true cost: 2 0.21424996852874756
#
# end-to-end cost: 0.36507630348205566
# 2-stage    cost: 0.8133523464202881
# TRUE
# CHOSEN  true cost: 3 0.24041777849197388
# RANDOM  true cost:  -1 0.28546315679947537
# OPTIMAL true cost: 3 0.24041777849197388
# REWARDL true cost: 2 0.2428044080734253
#
# end-to-end cost: 0.3636946678161621
# 2-stage    cost: 2.408320426940918
# TRUE
# CHOSEN  true cost: 3 0.22645330429077148
# RANDOM  true cost:  -1 0.2735236572722594
# OPTIMAL true cost: 5 0.2259531021118164
# REWARDL true cost: 12 0.25014299154281616
#
# end-to-end cost: 0.19497595727443695
# 2-stage    cost: 2.634033203125
# TRUE
# CHOSEN  true cost: 1 0.1280595362186432
# RANDOM  true cost:  -1 0.15867488458752632
# OPTIMAL true cost: 2 0.12436170876026154
# REWARDL true cost: 2 0.12436170876026154
#
# end-to-end cost: 0.13702282309532166
# 2-stage    cost: 6.513907432556152
# TRUE
# CHOSEN  true cost: 4 0.08687938749790192
# RANDOM  true cost:  -1 0.12066621147096157
# OPTIMAL true cost: 2 0.08104509115219116
# REWARDL true cost: 2 0.08104509115219116
#
# end-to-end cost: 0.22824063897132874
# 2-stage    cost: 1.2026948928833008
# TRUE
# CHOSEN  true cost: 2 0.207742378115654
# RANDOM  true cost:  -1 0.21340313677986464
# OPTIMAL true cost: 15 0.19137951731681824
# REWARDL true cost: 2 0.207742378115654
#
# end-to-end cost: 0.19439741969108582
# 2-stage    cost: 6.123445510864258
# TRUE
# CHOSEN  true cost: 2 0.10893696546554565
# RANDOM  true cost:  -1 0.15243475697934628
# OPTIMAL true cost: 2 0.10893696546554565
# REWARDL true cost: 2 0.10893696546554565
#
# end-to-end cost: 0.30660301446914673
# 2-stage    cost: 0.07252144813537598
# TRUE
# CHOSEN  true cost: 1 0.23232315480709076
# RANDOM  true cost:  -1 0.2586333391567071
# OPTIMAL true cost: 1 0.23232315480709076
# REWARDL true cost: 2 0.2329987734556198
#
# end-to-end cost: 0.32117760181427
# 2-stage    cost: 4.62363338470459
# TRUE
# CHOSEN  true cost: 5 0.20256488025188446
# RANDOM  true cost:  -1 0.24893896654248238
# OPTIMAL true cost: 3 0.20198391377925873
# REWARDL true cost: 2 0.2027909755706787
#
# end-to-end cost: 0.35702046751976013
# 2-stage    cost: 0.07821662724018097
# TRUE
# CHOSEN  true cost: 8 0.2592200040817261
# RANDOM  true cost:  -1 0.28985123584667843
# OPTIMAL true cost: 5 0.2539956271648407
# REWARDL true cost: 2 0.2551146447658539
#
# end-to-end cost: 0.21472272276878357
# 2-stage    cost: 8.066864013671875
# TRUE
# CHOSEN  true cost: 3 0.3743477463722229
# RANDOM  true cost:  -1 0.36664663689831894
# OPTIMAL true cost: 1 0.1441718339920044
# REWARDL true cost: 2 0.24973976612091064
#
# end-to-end cost: 0.1912597268819809
# 2-stage    cost: 0.2988944947719574
# TRUE
# CHOSEN  true cost: 1 0.15335938334465027
# RANDOM  true cost:  -1 0.1780849148829778
# OPTIMAL true cost: 1 0.15335938334465027
# REWARDL true cost: 2 0.15530505776405334
#
# end-to-end cost: 0.22867712378501892
# 2-stage    cost: 1.0696467161178589
# TRUE
# ...
# TRUE
# CHOSEN  true cost: 2 2.69191837310791
# RANDOM  true cost:  -1 1.5622147594889004
# OPTIMAL true cost: 14 0.2931361794471741
# REWARDL true cost: 2 2.69191837310791
#
# end-to-end cost: 0.10615931451320648
# 2-stage    cost: 0.5234289169311523
# TRUE
# CHOSEN  true cost: 22 0.1222354993224144
# RANDOM  true cost:  -1 0.15710770121465126
# OPTIMAL true cost: 0 0.10615931451320648
# REWARDL true cost: 2 0.16610044240951538
#
# end-to-end cost: 0.35640057921409607
# 2-stage    cost: 5.5064697265625
# TRUE
# CHOSEN  true cost: 2 0.08855095505714417
# RANDOM  true cost:  -1 0.14609835917750993
# OPTIMAL true cost: 2 0.08855095505714417
# REWARDL true cost: 2 0.08855095505714417
#
# end-to-end cost: 0.18788008391857147
# 2-stage    cost: 0.10365267097949982
# TRUE
# CHOSEN  true cost: 23 0.18817022442817688
# RANDOM  true cost:  -1 0.21147894548873106
# OPTIMAL true cost: 20 0.18732953071594238
# REWARDL true cost: 2 0.22231173515319824
#
# end-to-end cost: 0.17653313279151917
# 2-stage    cost: 7.730213165283203
# TRUE
# CHOSEN  true cost: 2 0.14096301794052124
# RANDOM  true cost:  -1 0.2045498201623559
# OPTIMAL true cost: 4 0.11712398380041122
# REWARDL true cost: 2 0.14096301794052124
#
# end-to-end cost: 0.26324155926704407
# 2-stage    cost: 0.10748621821403503
# TRUE
# CHOSEN  true cost: 2 0.24540744721889496
# RANDOM  true cost:  -1 0.245570237437884
# OPTIMAL true cost: 15 0.21936669945716858
# REWARDL true cost: 2 0.24540744721889496
#
# end-to-end cost: 0.2247539609670639
# 2-stage    cost: 5.469796657562256
# TRUE
# CHOSEN  true cost: 2 0.14640262722969055
# RANDOM  true cost:  -1 0.20522359448174635
# OPTIMAL true cost: 1 0.14556515216827393
# REWARDL true cost: 2 0.14640262722969055
#
# end-to-end cost: 0.12022554874420166
# 2-stage    cost: 2.2010416984558105
# TRUE
# CHOSEN  true cost: 1 0.17426562309265137
# RANDOM  true cost:  -1 0.13316694553941488
# OPTIMAL true cost: 4 0.10199042409658432
# REWARDL true cost: 2 0.1755112260580063
#
# end-to-end cost: 0.11915849894285202
# 2-stage    cost: 2.3815789222717285
# TRUE
# CHOSEN  true cost: 2 0.10556440055370331
# RANDOM  true cost:  -1 0.12235878283778827
# OPTIMAL true cost: 1 0.10100829601287842
# REWARDL true cost: 2 0.10556440055370331
#
# end-to-end cost: 0.11467751115560532
# 2-stage    cost: 2.826160192489624
# TRUE
# CHOSEN  true cost: 23 0.12032829970121384
# RANDOM  true cost:  -1 0.12217415869235992
# OPTIMAL true cost: 1 0.1048813909292221
# REWARDL true cost: 2 0.10724111646413803
#
# end-to-end cost: 0.129082590341568
# 2-stage    cost: 0.47631996870040894
# TRUE
# CHOSEN  true cost: 23 0.13209646940231323
# RANDOM  true cost:  -1 0.14882420810560384
# OPTIMAL true cost: 0 0.129082590341568
# REWARDL true cost: 2 0.15128837525844574
#
# end-to-end cost: 0.09196889400482178
# 2-stage    cost: 6.646232604980469
# TRUE
# CHOSEN  true cost: 2 0.17278602719306946
# RANDOM  true cost:  -1 0.11406115380426247
# OPTIMAL true cost: 10 0.0867282897233963
# REWARDL true cost: 2 0.17278602719306946
#
# end-to-end cost: 0.17952001094818115
# 2-stage    cost: 1.115346908569336
# TRUE
# CHOSEN  true cost: 12 0.21443144977092743
# RANDOM  true cost:  -1 0.2037444350620111
# OPTIMAL true cost: 0 0.17952001094818115
# REWARDL true cost: 2 0.2133558839559555
#
# end-to-end cost: 0.2495547980070114
# 2-stage    cost: 2.4430081844329834
# TRUE
# CHOSEN  true cost: 2 0.169502854347229
# RANDOM  true cost:  -1 0.19936895743012428
# OPTIMAL true cost: 5 0.1693885624408722
# REWARDL true cost: 2 0.169502854347229
#
# end-to-end cost: 0.17780175805091858
# 2-stage    cost: 0.8963057994842529
# TRUE
# CHOSEN  true cost: 1 0.10536273568868637
# RANDOM  true cost:  -1 0.20674417912960052
# OPTIMAL true cost: 2 0.1050628051161766
# REWARDL true cost: 2 0.1050628051161766
#
# end-to-end cost: 0.11839272826910019
# 2-stage    cost: 4.2200798988342285
# TRUE
# CHOSEN  true cost: 1 0.4937640428543091
# RANDOM  true cost:  -1 0.3371054135883848
# OPTIMAL true cost: 0 0.11839272826910019
# REWARDL true cost: 2 0.5524176359176636
#
# end-to-end cost: 0.09027314186096191
# 2-stage    cost: 4.522902488708496
# TRUE
# CHOSEN  true cost: 23 0.09732988476753235
# RANDOM  true cost:  -1 0.09969982349624236
# OPTIMAL true cost: 21 0.07534997910261154
# REWARDL true cost: 2 0.0947895273566246
#
# end-to-end cost: 0.8868207931518555
# 2-stage    cost: 7.219644546508789
# TRUE
# CHOSEN  true cost: 23 0.8965694308280945
# RANDOM  true cost:  -1 0.2775620597725113
# OPTIMAL true cost: 1 0.094033382833004
# REWARDL true cost: 2 0.09888429939746857
#
# end-to-end cost: 0.1002647876739502
# 2-stage    cost: 3.224760055541992
# TRUE
# CHOSEN  true cost: 23 0.10824769735336304
# RANDOM  true cost:  -1 0.16100547897318998
# OPTIMAL true cost: 0 0.1002647876739502
# REWARDL true cost: 2 0.15481136739253998
#
# end-to-end cost: 0.10353097319602966
# 2-stage    cost: 7.174107551574707
# TRUE
# CHOSEN  true cost: 23 0.10977798700332642
# RANDOM  true cost:  -1 0.15141435681531826
# OPTIMAL true cost: 0 0.10353097319602966
# REWARDL true cost: 2 0.16507627069950104
#
# end-to-end cost: 0.19316324591636658
# 2-stage    cost: 1.0438586473464966
# TRUE
# CHOSEN  true cost: 23 0.19287876784801483
# RANDOM  true cost:  -1 0.2164018570135037
# OPTIMAL true cost: 20 0.18921229243278503
# REWARDL true cost: 2 0.23013423383235931
#
# end-to-end cost: 0.17381373047828674
# 2-stage    cost: 4.9883341789245605
# TRUE
# CHOSEN  true cost: 2 0.10547643154859543
# RANDOM  true cost:  -1 0.14016953265915313
# OPTIMAL true cost: 1 0.10413601249456406
# REWARDL true cost: 2 0.10547643154859543
#
# end-to-end cost: 0.11183786392211914
# 2-stage    cost: 7.087479591369629
# TRUE
# CHOSEN  true cost: 2 0.38970470428466797
# RANDOM  true cost:  -1 0.19683699620266756
# OPTIMAL true cost: 0 0.11183786392211914
# REWARDL true cost: 2 0.38970470428466797
#
# end-to-end cost: 0.19021885097026825
# 2-stage    cost: 1.2743734121322632
# TRUE
# CHOSEN  true cost: 2 0.17845289409160614
# RANDOM  true cost:  -1 0.18537287910779318
# OPTIMAL true cost: 15 0.1707877814769745
# REWARDL true cost: 2 0.17845289409160614
#
# end-to-end cost: 0.14588162302970886
# 2-stage    cost: 8.71459674835205
# TRUE
# CHOSEN  true cost: 2 0.1509283185005188
# RANDOM  true cost:  -1 0.15710041299462318
# OPTIMAL true cost: 4 0.11378805339336395
# REWARDL true cost: 2 0.1509283185005188
#
# end-to-end cost: 0.14963790774345398
# 2-stage    cost: 2.618182897567749
# TRUE
# CHOSEN  true cost: 2 0.11553482711315155
# RANDOM  true cost:  -1 0.1393036919956406
# OPTIMAL true cost: 1 0.11386451125144958
# REWARDL true cost: 2 0.11553482711315155
#
# end-to-end cost: 0.15894266963005066
# 2-stage    cost: 5.999381065368652
# TRUE
# CHOSEN  true cost: 2 0.13143287599086761
# RANDOM  true cost:  -1 0.14982042461633682
# OPTIMAL true cost: 1 0.12863853573799133
# REWARDL true cost: 2 0.13143287599086761
#
# end-to-end cost: 0.25476694107055664
# 2-stage    cost: 0.6963937282562256
# TRUE
# CHOSEN  true cost: 22 0.24849896132946014
# RANDOM  true cost:  -1 0.25246470359464485
# OPTIMAL true cost: 15 0.22339217364788055
# REWARDL true cost: 2 0.2591869533061981
#
# end-to-end cost: 0.27113598585128784
# 2-stage    cost: 0.031323324888944626
# TRUE
# CHOSEN  true cost: 2 0.1416647583246231
# RANDOM  true cost:  -1 0.19231625149647394
# OPTIMAL true cost: 3 0.14022749662399292
# REWARDL true cost: 2 0.1416647583246231
#
# end-to-end cost: 0.25774672627449036
# 2-stage    cost: 2.5016326904296875
# TRUE
# CHOSEN  true cost: 4 0.12521912157535553
# RANDOM  true cost:  -1 0.18111656699329615
# OPTIMAL true cost: 3 0.12342603504657745
# REWARDL true cost: 2 0.1256619393825531
#
# end-to-end cost: 0.19500426948070526
# 2-stage    cost: 3.880678653717041
# TRUE
# CHOSEN  true cost: 1 0.16561070084571838
# RANDOM  true cost:  -1 0.2861284961303075
# OPTIMAL true cost: 1 0.16561070084571838
# REWARDL true cost: 2 0.22505995631217957
#
# end-to-end cost: 0.934805154800415
# 2-stage    cost: 8.329607963562012
# TRUE
# CHOSEN  true cost: 1 0.9705280065536499
# RANDOM  true cost:  -1 0.5131633263081312
# OPTIMAL true cost: 17 0.14061997830867767
# REWARDL true cost: 2 0.8184278011322021
#
# end-to-end cost: 0.09961971640586853
# 2-stage    cost: 0.40920305252075195
# TRUE
# CHOSEN  true cost: 23 0.10676693916320801
# RANDOM  true cost:  -1 0.15156045742332935
# OPTIMAL true cost: 0 0.09961971640586853
# REWARDL true cost: 2 0.16541506350040436
#
# end-to-end cost: 0.1917952001094818
# 2-stage    cost: 8.05339527130127
# TRUE
# CHOSEN  true cost: 12 0.1734180450439453
# RANDOM  true cost:  -1 0.16343125204245249
# OPTIMAL true cost: 4 0.11917559802532196
# REWARDL true cost: 2 0.15513299405574799
#
# end-to-end cost: 0.2616655230522156
# 2-stage    cost: 2.2708849906921387
# TRUE
# CHOSEN  true cost: 23 0.2678317725658417
# RANDOM  true cost:  -1 0.1803969635317723
# OPTIMAL true cost: 1 0.13710474967956543
# REWARDL true cost: 2 0.14666172862052917
#
# end-to-end cost: 0.10254046320915222
# 2-stage    cost: 2.5468578338623047
# TRUE
# CHOSEN  true cost: 4 0.09133237600326538
# RANDOM  true cost:  -1 0.09615066771705945
# OPTIMAL true cost: 1 0.0786171555519104
# REWARDL true cost: 2 0.08172759413719177
#
# end-to-end cost: 0.15973961353302002
# 2-stage    cost: 0.8915141820907593
# TRUE
# CHOSEN  true cost: 1 0.11363537609577179
# RANDOM  true cost:  -1 0.13605719214926162
# OPTIMAL true cost: 2 0.11189420521259308
# REWARDL true cost: 2 0.11189420521259308
#
# end-to-end cost: 0.19855201244354248
# 2-stage    cost: 0.2418605089187622
# TRUE
# CHOSEN  true cost: 1 0.12948791682720184
# RANDOM  true cost:  -1 0.1553308106958866
# OPTIMAL true cost: 2 0.12677349150180817
# REWARDL true cost: 2 0.12677349150180817
#
# end-to-end cost: 0.26229149103164673
# 2-stage    cost: 0.05623394250869751
# TRUE
# CHOSEN  true cost: 1 0.17268800735473633
# RANDOM  true cost:  -1 0.2056119783471028
# OPTIMAL true cost: 2 0.17105506360530853
# REWARDL true cost: 2 0.17105506360530853
#
# end-to-end cost: 0.317638635635376
# 2-stage    cost: 0.028903134167194366
# TRUE
# CHOSEN  true cost: 2 0.17413243651390076
# RANDOM  true cost:  -1 0.2278295929233233
# OPTIMAL true cost: 3 0.1710740327835083
# REWARDL true cost: 2 0.17413243651390076
#
# end-to-end cost: 0.41076692938804626
# 2-stage    cost: 0.48269233107566833
# TRUE
# CHOSEN  true cost: 8 0.25261056423187256
# RANDOM  true cost:  -1 0.3016707810262839
# OPTIMAL true cost: 4 0.2399216592311859
# REWARDL true cost: 2 0.2457829713821411
#
# end-to-end cost: 0.4148695468902588
# 2-stage    cost: 0.8560972213745117
# TRUE
# CHOSEN  true cost: 3 0.23695413768291473
# RANDOM  true cost:  -1 0.30220653551320237
# OPTIMAL true cost: 4 0.23599892854690552
# REWARDL true cost: 12 0.2745189070701599
#
# end-to-end cost: 0.33921799063682556
# 2-stage    cost: 2.7956228256225586
# TRUE
# CHOSEN  true cost: 4 0.17765125632286072
# RANDOM  true cost:  -1 0.2616548705846071
# OPTIMAL true cost: 4 0.17765125632286072
# REWARDL true cost: 17 0.28027820587158203
#
# end-to-end cost: 0.22318367660045624
# 2-stage    cost: 4.810943126678467
# TRUE
# CHOSEN  true cost: 1 1.836970567703247
# RANDOM  true cost:  -1 2.0739177968353033
# OPTIMAL true cost: 20 0.20632730424404144
# REWARDL true cost: 2 2.4248576164245605
#
# end-to-end cost: 0.5593310594558716
# 2-stage    cost: 4.706452369689941
# TRUE
# CHOSEN  true cost: 1 0.5247880220413208
# RANDOM  true cost:  -1 0.28493997268378735
# OPTIMAL true cost: 14 0.08797784149646759
# REWARDL true cost: 2 0.4534072279930115
#
# end-to-end cost: 0.1869528591632843
# 2-stage    cost: 3.364387273788452
# TRUE
# CHOSEN  true cost: 23 0.19340863823890686
# RANDOM  true cost:  -1 0.12063344785322745
# OPTIMAL true cost: 21 0.08712127059698105
# REWARDL true cost: 2 0.1106220930814743
#
# end-to-end cost: 0.1480993926525116
# 2-stage    cost: 0.054431598633527756
# TRUE
# CHOSEN  true cost: 23 0.1492404043674469
# RANDOM  true cost:  -1 0.17508899172147116
# OPTIMAL true cost: 0 0.1480993926525116
# REWARDL true cost: 2 0.1871962994337082
#
# end-to-end cost: 0.1440378725528717
# 2-stage    cost: 11.391853332519531
# TRUE
# CHOSEN  true cost: 1 0.10613753646612167
# RANDOM  true cost:  -1 0.13392550715555748
# OPTIMAL true cost: 1 0.10613753646612167
# REWARDL true cost: 2 0.1092182993888855
#
# end-to-end cost: 0.3245663046836853
# 2-stage    cost: 0.12544067203998566
# TRUE
# CHOSEN  true cost: 2 0.29325538873672485
# RANDOM  true cost:  -1 0.2939185289045175
# OPTIMAL true cost: 15 0.26318585872650146
# REWARDL true cost: 2 0.29325538873672485
#
# end-to-end cost: 0.28045567870140076
# 2-stage    cost: 1.8587102890014648
# TRUE
# CHOSEN  true cost: 2 0.1155521497130394
# RANDOM  true cost:  -1 0.18461577408015728
# OPTIMAL true cost: 3 0.11002513021230698
# REWARDL true cost: 2 0.1155521497130394
#
# end-to-end cost: 0.23863419890403748
# 2-stage    cost: 3.293428421020508
# TRUE
# CHOSEN  true cost: 4 0.12982875108718872
# RANDOM  true cost:  -1 0.23272722121328115
# OPTIMAL true cost: 2 0.09679627418518066
# REWARDL true cost: 2 0.09679627418518066
#
# end-to-end cost: 0.2514883279800415
# 2-stage    cost: 0.31427377462387085
# TRUE
# CHOSEN  true cost: 1 0.14538636803627014
# RANDOM  true cost:  -1 0.18569314169387022
# OPTIMAL true cost: 3 0.13847118616104126
# REWARDL true cost: 2 0.13940109312534332
#
# end-to-end cost: 0.323102205991745
# 2-stage    cost: 0.06132480502128601
# TRUE
# CHOSEN  true cost: 9 0.19589200615882874
# RANDOM  true cost:  -1 0.23003589486082396
# OPTIMAL true cost: 3 0.17474310100078583
# REWARDL true cost: 2 0.17768995463848114
#
# end-to-end cost: 0.2961382269859314
# 2-stage    cost: 3.5469794273376465
# TRUE
# CHOSEN  true cost: 2 0.12556560337543488
# RANDOM  true cost:  -1 0.211476548264424
# OPTIMAL true cost: 3 0.1186756044626236
# REWARDL true cost: 2 0.12556560337543488
#
# end-to-end cost: 0.3276319205760956
# 2-stage    cost: 1.8107455968856812
# TRUE
# CHOSEN  true cost: 8 0.20628540217876434
# RANDOM  true cost:  -1 0.2448572013527155
# OPTIMAL true cost: 3 0.19530069828033447
# REWARDL true cost: 2 0.1968580186367035
#
# end-to-end cost: 0.35136088728904724
# 2-stage    cost: 0.12349161505699158
# TRUE
# CHOSEN  true cost: 1 0.26053309440612793
# RANDOM  true cost:  -1 0.287614652266105
# OPTIMAL true cost: 2 0.26010215282440186
# REWARDL true cost: 2 0.26010215282440186
#
# end-to-end cost: 0.24555622041225433
# 2-stage    cost: 3.603417158126831
# TRUE
# CHOSEN  true cost: 2 0.10805708169937134
# RANDOM  true cost:  -1 0.19674059003591537
# OPTIMAL true cost: 3 0.10618306696414948
# REWARDL true cost: 12 0.14804992079734802
#
# end-to-end cost: 0.22447741031646729
# 2-stage    cost: 3.4554667472839355
# TRUE
# CHOSEN  true cost: 2 0.10370713472366333
# RANDOM  true cost:  -1 0.20441038285692534
# OPTIMAL true cost: 2 0.10370713472366333
# REWARDL true cost: 2 0.10370713472366333
#
# end-to-end cost: 0.20184795558452606
# 2-stage    cost: 2.1907002925872803
# TRUE
# CHOSEN  true cost: 2 0.0946580022573471
# RANDOM  true cost:  -1 0.18837470716486374
# OPTIMAL true cost: 2 0.0946580022573471
# REWARDL true cost: 2 0.0946580022573471
#
# end-to-end cost: 0.18663161993026733
# 2-stage    cost: 2.163356304168701
# TRUE
# CHOSEN  true cost: 2 0.11821869015693665
# RANDOM  true cost:  -1 0.201431715550522
# OPTIMAL true cost: 1 0.09519167989492416
# REWARDL true cost: 2 0.11821869015693665
#
# end-to-end cost: 0.16659879684448242
# 2-stage    cost: 3.54148006439209
# TRUE
# CHOSEN  true cost: 2 0.19405774772167206
# RANDOM  true cost:  -1 0.2995441847791274
# OPTIMAL true cost: 17 0.15221089124679565
# REWARDL true cost: 2 0.19405774772167206
#
# end-to-end cost: 0.33137190341949463
# 2-stage    cost: 0.6699404120445251
# TRUE
# CHOSEN  true cost: 2 0.26762908697128296
# RANDOM  true cost:  -1 0.2821955184141795
# OPTIMAL true cost: 15 0.25535666942596436
# REWARDL true cost: 2 0.26762908697128296
#
# end-to-end cost: 0.43029695749282837
# 2-stage    cost: 0.03911001235246658
# TRUE
# CHOSEN  true cost: 2 0.24976786971092224
# RANDOM  true cost:  -1 0.30492535171409446
# OPTIMAL true cost: 4 0.2392546534538269
# REWARDL true cost: 2 0.24976786971092224
#
# end-to-end cost: 0.37448716163635254
# 2-stage    cost: 1.110166072845459
# TRUE
# CHOSEN  true cost: 5 0.1675984263420105
# RANDOM  true cost:  -1 0.2523958347737789
# OPTIMAL true cost: 5 0.1675984263420105
# REWARDL true cost: 17 0.29689115285873413
#
# end-to-end cost: 0.40520498156547546
# 2-stage    cost: 0.03275946527719498
# TRUE
# CHOSEN  true cost: 4 0.21463891863822937
# RANDOM  true cost:  -1 0.2849193488558133
# OPTIMAL true cost: 5 0.2144630402326584
# REWARDL true cost: 1 0.24619774520397186
#
# end-to-end cost: 0.4774412512779236
# 2-stage    cost: 1.538418173789978
# TRUE
# CHOSEN  true cost: 2 0.29007062315940857
# RANDOM  true cost:  -1 0.34256964176893234
# OPTIMAL true cost: 3 0.28181761503219604
# REWARDL true cost: 2 0.29007062315940857

# %%
# best sinle action
avg_cost_per_action = np.mean(all_costs, axis=0)
all_costs = np.array(all_costs)

single_action=1
# single_action = np.argmin(avg_cost_per_action)

# %%
print("VANILLA e2e", np.mean(vanilla), np.std(vanilla))
print("Our app    ", np.mean(ours), np.std(ours))
print("Reward    ", np.mean(reward_losses), np.std(reward_losses))
print("random     ", np.mean(random), np.std(random))
print("optimal    ", np.mean(optimal), np.std(optimal))
print("2-s        ", np.mean(two_stage), np.std(two_stage))
print("single ac  ", avg_cost_per_action[single_action], single_action)
# Out:
# VANILLA e2e 0.3416497173000576 0.15759335290045912
# Our app     0.2344044741004099 0.18334679132974632
# Reward     0.242294161415809 0.18659798342745268
# random      0.26286865825228967 0.1326009546746231
# optimal     0.19231618123481717 0.060190846601738235
# 2-s         1.4667654952139293 1.949003708463955
# single ac   0.23592908297999177 1

# %%
QUANTILE = 0.5
print("VANILLA e2e  ", np.quantile(vanilla, QUANTILE), np.std(vanilla))
print("Our app      ", np.quantile(ours, QUANTILE), np.std(ours))
print("random       ", np.quantile(random, QUANTILE), np.std(random))
print("reward       ", np.quantile(reward_losses, QUANTILE), np.std(random))
print("optimal      ", np.quantile(optimal, QUANTILE), np.std(optimal))
print("single ac    ", np.quantile(all_costs[:,single_action], QUANTILE))
print("2-stage      ", np.quantile(two_stage, QUANTILE), np.std(two_stage))
# Out:
# VANILLA e2e   0.33921799063682556 0.15759335290045912
# Our app       0.20388516783714294 0.18334679132974632
# random        0.2492748306443294 0.1326009546746231
# reward        0.2146483063697815 0.1326009546746231
# optimal       0.1873791664838791 0.060190846601738235
# single ac     0.2131691575050354
# 2-stage       0.5881593227386475 1.949003708463955

# %%
print(sum(np.array(ours) <= np.array(all_costs[:,single_action])) / len(ours))
# Out:
# 0.7230046948356808

# %%
print(sum(np.array(ours) <= np.array(random)) / len(ours))
# Out:
# 0.9405320813771518

# %%
print(sum(np.array(ours) <= np.array(vanilla)) / len(ours))
# Out:
# 0.9530516431924883

# %%
print(sum(np.array(ours) <= np.array(reward_losses)) / len(ours))
# Out:
# 0.6353677621283255

# %%
import matplotlib.pyplot as plt

bins = 20

cm = 1/2.54  # centimeters in inches
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(80*cm, 20*cm))
ax1.hist([ours, optimal], label=['endogenous E2E', 'optimal'], bins=bins, histtype='step', range=[0, 0.6])
ax1.legend(fontsize="18")
ax2.hist([all_costs[:,single_action], optimal], label=['single action', 'optimal'], bins=bins, histtype='step', range=[0,0.6])
ax2.legend(fontsize="18")
ax3.hist([random, optimal], label=['random', 'optimal'], bins=bins, histtype='step', range=[0,0.6])
ax3.legend(fontsize="18")
ax4.hist([reward_losses, optimal], label=['cost learner', 'optimal'], bins=bins, histtype='step', range=[0,0.6])
ax4.legend(fontsize="18")

# %%
all_costs = np.array(all_costs)

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(x=[i for i in range(24)], y=, mode='lines', name='data', marker=dict(color='green')))
fig.update_layout(xaxis_title='alpha', yaxis_title='Loss', title='Loss at w = 0.25, g(w,z)=1', width = 600, height = 600)
